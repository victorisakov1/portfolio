# %% [markdown]
# # Kolobok Fairytale.
#
#
# The little round bun (Kolobok). Russian Crafts. (n.d.). https://russian-crafts.com/russian-folk-tales/kolobok.html
# There is no one specific author of this story as it is a Russian Folk Fairytale. So you could read the story at the link above.
#
#
#    INTRODUCTION TO THE FAIRYTALE:
#
#    Once upon a time, there was a poor old couple. They lived in a village in an old-old house right by the forest. There was a river running by that forest and the cleanest air. The couple had their own garden and had their own organic food. But this year was colder than others and they had very little food. And one day wife decided to bake a special treat for her husband. And she found out there was just enough flour to make a type of bun called Kolobok. When grandma was done, she placed it on a window-still to cool down...
#
#    The story starts here and you will decide the destiny of Kolobok! You will face some difficult choices, meet new characters, and decide what to do to pass this journey.
#
# ---------------------------------------------------------------------------------------------------------------------------
#
#    BUGS THAT ARE NOT YET WORKED OUT:
#
#    - For some inputs, you can't combine two answer choices in one, otherwise it will give a mistaken answer.
#    - If you don't respond - game won't continue and will wait for your input.
#    - If your answer is not recognized by the code - it will ask you to either try again, where you must select yes or 1 as      an answer, otherwise you will lose.
#    - For some questions, there is no limit to the amount of times you can put an invalid answer choice.
#    - For one question, it says [Choose one number] where you must choose a number only. You will have 3 chances to make a        choice, and then it will randomly select the direction for you.
#    - Some questions where you need to decide the direction (after house stage) will allow 3 attempts and will choose a          direction for you if your choice didn't match the proposed options.
#
#
#   INSTRUCTIONS:
#
#   Choose the directions provided in the game to make Kolobok's next move. In some situations you will be prompted to give names for the characters throughout the journey. Good Luck!

# %%
import time
import random
   
    #mandatory stage_1 - House
def house():
    print("""
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠶⣦⣄⡴⠛⠁⠀⠀⢀⡀⣀⣠⠤⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠻⠁⠀⠀⠀⠀⠀⠈⠉⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⣴⣤⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⡟⠁⠳⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣴⣯⣿⣧⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡠⣫⣿⡷⣲⡹⢿⣏⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣮⣷⣿⣿⣿⣷⣿⣾⣯⣷⣏⣷⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡴⡷⠐⢿⣯⣟⣿⡯⡿⣟⣽⣳⣿⡧⢯⣿⣼⡆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⢏⡶⣿⠆⢰⡛⣷⢿⢽⣵⣿⠟⣯⣿⣞⡵⣟⡟⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣰⣗⡯⣥⣝⡟⣦⠹⣾⣫⣻⣿⣿⡯⡎⣿⡵⣟⠟⡆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡞⣝⢋⡟⠀⠀⢻⣫⣦⡈⢛⣽⢿⣿⣿⡟⡿⡿⠃⠀⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣼⡷⣣⣻⠁⠀⠀⠀⢻⡎⣫⣆⠘⣿⣷⡿⡫⠏⠁⠀⠀⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠸⣏⣟⡹⠁⠀⠀⠀⠀⠀⠳⡗⢧⣀⣜⠯⠏⠁⠀⠀⠀⠀⣾⠀⠄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⠀⠀⣦⡄⠀⠀⠀⠀⠀⠀⠈⠁⢧⢠⠀⠀⠀⠀⢀⣶⠎⠄⠀⠀⠀⠀⠀⠀⡀⡀⡀⣀⣀⣀⡀⣀⣀⡀
⠀⠀⠀⡀⣀⡤⡤⠴⠄⡇⠀⠀⠉⠀⠀⣴⣟⣯⣇⠀⠀⠀⠀⣿⠀⠀⠀⠀⣴⠟⠉⠉⠉⠛⠛⠛⠛⠓⠚⠮⠠⠿⠾⠇⠵⠿⡷⠻⣿
⣪⠟⠃⠈⠀⠀⠀⠀⠀⠘⡆⠀⠀⠀⠀⣿⣿⡗⢻⡇⠀⠀⠀⢻⢀⢀⣴⠞⠁⠀⠀⠀⠀⠀⠀⠀⠄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑
⠀⠀⠀⠀⠐⠀⠀⠀⠀⠀⠀⠹⣆⡀⠀⡻⠿⠷⣿⡇⠀⠀⣀⡜⠋⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠁⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠁⠀⠀⠀⠀⠉⢱⣿⣿⣿⣿⠉⠉⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠂⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠄⠀⠀⠄⠀⠀⠈⠀⠀⠀⠀⣀⣿⣿⣿⣿⠁⠀⠀⠀⠀⠀⢀⠀⠀⠀⠀⠀⠀⠀⠈⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠄⠀⠀⠀⠁⠀
⠀⠀⠀⠀⠀⠀⢀⠀⠀⠀⢠⣴⣿⣿⣿⣿⣿⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠁⠀⠀⠀⠀⠀⣴⣿⣿⣿⣿⣿⣿⠅⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡀⠀⠀⠀⠀⠀⢀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠐
⠀⠀⠀⠀⠀⠀⠀⢠⣿⣿⣿⣿⣿⣿⣿⡏⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠄⠀⠀⠀⣾⣿⣿⣿⣿⣿⣿⣿⡯⠀⠀⠀⠂⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⠁⠀⠀⠀⠀⠀⠀⠀⠀⠂⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⣟⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠁⠀⠀⠀⠀
⠀⠀⣀⣿⣿⣿⣿⣿⣿⣿⣿⠏⠂⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠠⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⢀⣾⣿⣿⣿⣿⣿⣿⣿⣿⡟⠀⠀⠀⠀⡀⠀⠀⠀⠀⠀⡀⠀⠀⠀⠀⠄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⣿⣿⣿⣿⣿⣿⣿⣿⡿⠃⠀⠀⠀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠐⠀⠀⠀⠀⠀⠀⠀⠀⠀⠄⠀⠀⠀⠀⠀⠀⠁⠀
⣿⣿⣿⣿⣿⣿⣿⠟⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀


You start your journey where grandma put you - on a window-still.
""")
    #Prompting user to start the game with Enter key
    input(prompt = "<Press Enter to Start Kolobok's Journey>\n")
    
    print(
"""
What will you do next? [Choose one option]
1. Wait until I cool down.
2. Roll to the kitchen.
3. Escape through the window.""")
    
    #Prompting user for their choice and casefold() will make user's input as lowercase
    choice_1 = input(prompt = "-> ").casefold()
    
    #if their choice matches the possibile answers below - they will fail
    if choice_1 == "1" or choice_1 == "1." or "wait until I cool down" in choice_1 or "wait" in choice_1 or "cool" in choice_1:
        print("You cooled down and it was time to eat. So Grandma and Grandpa decided to eat you.\n")
        fail()
        
    #if their choice matches the possibile answers below - they will fail
    elif choice_1 == "2" or choice_1 == "2." or "roll to the kitchen" in choice_1 or "roll" in choice_1 or "kitchen" in choice_1:
        print("They saw you moving! Grandma had a heart attack and grandpa had to wash you and ate for her funeral.\n")
        fail()
    
    #if their choice matches the possibile answers below - they will go further    
    elif choice_1 == "3" or choice_1 == "3." or "escape through the window" in choice_1 or "escape" in choice_1 or "window" in choice_1:
        print("Kolobok rolled out of the window, rolled to the garden, and kept rolling until it reached forest.\n")
        rolling_1()
    
    #if their answer is not defined by my code - they will be prompted to restart the stage or to exit the stage
    else:
        print(
"""
There is no such answer :\ Try Again?
> Yes
> Exit""")
        
        #once the user inputs "wrong" answer - they will be prompted to try again or exit stage
        try_again = input(prompt = "-> ").casefold()
        
        #if they say "yes" or "1" - they will restart the stage
        if "yes" in try_again or try_again == "1":
            house()
            
        #otherwise - they will exit stage
        else:
            fail()

    #this is a choice of direction which is not considered a stage
def rolling_1():
    
    #defining "direction" through a random selection of possible direction from my list
    direction = random.choice([village, forest_1])
    
    #giving 3 chances
    chances = 3
    print( 
"""
─═──═──═─୧⍤⃝─═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──
Where are you rolling now? [Choose a number]
1. Turn left to another village.
2. Go deeper into the forest.""")
    
    #while loop which runs until chances > 0
    while chances > 0:    
        
        #checking that user input is an integer
        try:
            choice_2 = int(input(prompt = "-> "))
            #if the number is 1 then user goes to the optional stage_2 village() and chances = 0 so when the stage finishes, loop doesn't rerun
            if choice_2 == 1:
                print("Kolobok decided to turn left. It took you some time to get to the village.")
                village()
                chances = 0
            
            #if choice = 2 then user goes to the next mandatory stage_2 forest_1()
            elif choice_2 == 2:
                print("Kolobok looked around, and decided to go into the forest.")
                forest_1()
                chances = 0
            
            #if the number is not 1 or 2, then user gets to use the chances (3 total)
            else:
                print("Invalid entry. PLease, enter 1 or 2.")
                chances -= 1
                
                #if there are more than 0 chances - prompt will reappear
                if chances > 0:
                    print("Try Again")
                    
                #if there are no more chances - direction will be randomly selected for the user
                elif chances == 0:
                    print(f"You were indecisive so you rolled a dice.")
                    direction()
                    
                #otherwise, user will be prompted to restart the direction choice or exit
                else:
                    print(
"""
There is no such answer :\ Try Again?
> Yes
> Exit""")

                    try_again = input(prompt = "-> ").casefold()

                    if "yes" in try_again or try_again == "1":
                        rolling_1()
                    else:
                        fail()
        #if user puts something other than integer - there will be also 3 chances to put the number    
        except ValueError:
            chances -= 1 #every wrong choice reduces chances that are left
            
            #while chances are more than 0 - user will be prompted to try again
            if chances > 0:
                print("Try Again")
                
            #when chances reach 0 - random direction will be selected 
            elif chances == 0:
                print(f"You were indecisive so you rolled a dice.")
                direction()
            
            #otherwise, user will be prompted to restart the direction choice or exit 
            else:
                print("""
There is no such answer :\ Try Again?
> Yes
> Exit""")

                try_again = input(prompt = "-> ").casefold()

                if "yes" in try_again or try_again == "1":
                    rolling_1()
                else:
                    fail()

                    
    #optional stage 2 - Village 
def village():
    print(
"""
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⢀⣴⣶⣄⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠠⠴⠿⠿⠿⠿⠿⠦⠀⠀⢀⣤⡀⠀⠀⠀⠀⠀⠀⣠⣶⣷⣤⡀⠀⠀⠀⠀
⠀⠀⠀⢰⡶⢶⣶⣶⡶⠂⣀⣴⣿⣿⣿⣦⣀⠀⠀⠤⠾⠿⠿⠿⠿⠿⠦⠀⠀⠀
⠀⠀⠀⢸⣷⣾⠟⠋⣠⣾⣿⣿⣿⣿⣿⣿⣿⣷⣄⠀⢶⡶⢶⣶⣶⣶⡆⠀⠀⠀
⠀⠀⠀⠈⠉⠁⠀⠈⠉⡉⠉⣉⣉⣉⣉⣉⣉⣉⡉⠁⣀⣁⣾⣿⣿⠀⡇⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣦⡈⠻⢿⡏⠀⠈⣿⡇⠀⠀⢀⡀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⢀⣴⣿⣿⣿⣿⣦⣄⠙⢿⣿⡿⠃⣠⣾⣿⣿⣦⡀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⣠⣶⣿⣿⣿⣿⣿⣿⣿⣿⣷⣄⡈⠰⣾⣿⣿⣿⣿⣿⣿⣷⣄⠀⠀⠀
⠀⠀⠤⠾⠿⠿⠿⠿⠿⠿⠿⠿⠿⠿⠿⠿⠿⠦⠈⠉⠉⣉⣉⣉⣉⣉⡉⠉⠀⠀
⠀⠀⠀⠀⣴⣶⣶⣶⣶⣶⣶⣶⣶⣶⣶⣶⡆⢰⣶⣶⣶⠿⠿⠿⣿⣿⡇⠀⠀⠀
⠀⠀⠀⠀⣿⣿⠉⠉⠉⣿⣿⡿⠿⠿⢿⣿⡇⢸⣿⣿⣿⠀⠀⠀⣿⣿⡇⠀⠀⠀
⠀⠀⠀⠀⣿⣿⣀⣀⣀⣿⣿⡇⠀⠀⢸⣿⡇⠸⠿⠿⠿⠀⠀⠀⠿⠿⠇⠀⠀⠀
⠀⠀⠀⠀⢿⣿⣿⣿⣿⣿⣿⡇⠀⠀⢸⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀

⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
You went to the village, and there are people looking at you. What will you do next? [Choose one option]
1. Go towards villagers.
2. Turn to the Forest.""") 
    
    #giving 3 chances
    chances = 3    
    
    #while loop which runs until chances > 0
    while chances > 0:
        choice_3 = input(prompt = "-> ").casefold()
        
        #if their choice matches the possibile answers below - they will fail
        if choice_3 == "1" or choice_3 == "1." or "go towards villagers" in choice_3 or "go" in choice_3 or "towards" in choice_3 or "village" in choice_3:
            print("""
You are gladly rolling to villagers. You are happy and smiling, but they don't know you and see you as a tasty bun. 
So they grab you and eat with salt (In Russian tradition to eat Bread/Bun with salt).""")
            fail()
            chances = 0
        
        #if their choice matches the possibile answers below - they will move to the next mandatory stage_2 - forest_1
        elif choice_3 == "2" or choice_3 == "2." or "turn to the forest" in choice_3 or "turn" in choice_3 or "forest" in choice_3:
            print("""
⢀⠀⡀⢀⠐⠀⠀⠂⢀⠀⠀⠀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⢀⠈⡀⠁⠀⠈⠀⠁⠀⠀⠈⠀⠀⠀⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⢀⠂⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠠⠐⠈⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣠⣴⣴⣶⣴⢦⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⢐⠈⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣤⣶⠿⣿⣿⣿⣟⣯⣿⣿⣿⣿⣮⣍⣢⣄⠀⣀⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠠⠀⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⢿⣿⡾⣿⣿⣿⣯⣛⣼⣿⣿⣿⣿⣿⣿⣿⣿⣯⣿⣿⣿⣧⣄⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠠⠂⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣾⣿⣵⣶⣿⣷⢿⢿⡿⡿⣟⡻⢽⣻⣿⢿⣿⡿⢿⠺⡟⣿⠟⡻⣟⡋⢤⣄⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⢀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣰⣾⣾⢿⢿⣽⣿⣉⣿⣖⣯⣾⣾⣷⣾⣽⡴⣷⢟⢑⣰⢞⣶⣾⣿⠿⣿⡽⣷⣯⣿⡀⢄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠐⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣠⣽⣷⡿⣷⣿⣾⣦⣿⣿⣽⣿⣿⣿⣿⣿⢶⢿⣻⣿⠿⢿⣿⣿⣾⣼⣞⣿⣽⣟⣭⣿⣿⡼⢥⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠈⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣴⣿⣿⣿⠿⣿⣿⣿⢿⣿⡿⣿⣿⣿⢟⠋⢟⢛⢭⡛⣏⢈⣿⡧⣼⢟⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣯⠄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⢈⠐⠀⠀⠀⠀⠀⠀⠀⠀⢀⢿⣶⡯⡿⣲⣿⣻⣿⣿⣦⣿⡽⢟⣻⣿⣝⣮⣶⣶⣾⣿⣼⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠿⣿⡿⣿⣿⣳⣤⣤⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠠⠀⠀⠀⠀⠀⠀⢀⣴⣾⣯⣻⣾⣿⣭⣽⣿⣿⣿⣾⣯⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⢮⣿⣿⣻⣿⣿⣿⣿⣛⣛⣾⣚⢟⣢⣳⣦⣤⣝⣿⣿⡾⣥⣰⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠈⢀⠀⠀⠀⠀⠀⠐⠷⣯⣿⣟⣿⣭⣿⣷⣯⡿⠶⣏⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⡀⠈⣾⣿⣿⣟⣿⣿⡿⣻⣷⣟⣿⣿⣽⣿⣿⣷⢢⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠈⠀⠠⠀⠀⠀⠀⢀⣴⣽⣲⣿⣿⣷⣯⣿⣿⣾⣷⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡻⣭⢿⣛⣿⣿⣿⣿⣭⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⣿⠯⡿⣋⡭⣿⢇⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⢈⠀⠄⠀⠀⠀⠀⢹⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣟⣿⢿⣋⡥⣤⣬⣏⠻⣟⡻⠟⡛⣿⠟⠛⣿⣿⣿⣿⣿⣿⡟⡿⡟⢷⣿⣿⣿⣯⣷⢒⡄⠀⠀⠀⠀⠀⠀⠀⠀
⢀⠀⠀⠀⠀⠀⠾⣷⣿⣿⣿⣿⢻⣿⣿⣿⣻⣿⣿⣏⣿⣻⣿⣿⡷⠻⣿⣿⣾⣽⣱⣼⠿⣮⣿⣷⢿⣦⣿⡽⢿⣿⣿⣯⣝⣷⣿⣿⣻⡿⢾⠿⢿⣿⣿⣅⣀⡀⠀⠀⠀⠀⠀⠀⠀
⠈⠐⠠⠀⠀⠀⠀⠉⠙⡝⢭⣽⣎⣿⣽⣿⣻⣿⣿⣯⣯⣟⣿⣻⣧⣦⣿⣿⣭⣿⣿⣿⣦⣻⡿⣻⡼⣭⠿⡧⣚⣿⣿⣿⣿⣿⣽⣿⢏⡳⣾⣶⢾⣟⡿⣿⣟⠃⠀⠀⠀⠀⠀⠀⠀
⢈⠀⠀⠀⠀⠀⠀⢲⣽⡷⣿⣿⣿⣿⣿⣯⣿⣿⣷⣿⣿⣿⣿⣿⣿⣿⣿⡿⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣾⣾⣿⢏⢾⣿⣿⣿⣿⣷⣷⣽⣿⡿⢽⠛⢫⣝⠦⡄⠀⠀⠀⠀⠀⠀
⠠⠀⠄⠀⠀⠀⡁⠙⢿⣽⣿⣿⣿⢿⡿⢭⣩⣧⡘⢋⡛⡽⣶⣿⣯⣿⣻⣯⣔⢀⣼⣿⣿⣿⣿⣿⡿⣿⣿⣿⣿⡿⡻⣏⠿⢥⣾⣿⣿⣿⣿⣿⣻⣿⣿⣾⣿⡳⠓⠀⠀⠀⠀⢀⠀
⠰⢈⠀⠀⠌⡀⠀⣼⣯⣻⣟⢟⡿⣠⣶⢛⣿⣿⣿⣷⢛⣿⣷⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣢⣶⡿⣿⣿⣯⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣵⣿⣷⣷⣥⢄⠀⠄⡀⠀⡀⠀
⢘⠨⠀⠌⠐⡰⣟⣾⣾⢟⣿⠚⣻⣟⡿⣿⣿⣽⣿⣿⣿⣿⣿⣽⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣾⣯⣿⣿⣿⢿⢻⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣯⣗⠐⡈⡐⢠⠁
⢬⢃⡌⡄⣿⣿⢏⣽⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⢿⣿⣿⡟⢣⣾⣯⣶⣿⡿⢿⣿⣿⣿⠿⠻⠿⢿⣿⣿⣿⣿⣿⣿⣿⣿⣟⣿⠟⡐⡈⢄⢃
⣘⠦⡐⠜⢾⣿⢟⣻⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠟⢿⡿⣿⣿⣿⣿⣿⣷⣿⣿⡿⢋⠅⡄⠃⡌⢡⠠⣀⠂⣁⠂⠡⠉⡄⠡⢈⠋⡛⠊⠩⢀⠒⠤⡑⡈⢆
⣘⠦⡑⢌⠢⢡⠛⠿⢿⣿⡿⣿⠿⢻⠻⡝⠛⠿⠟⠻⢛⠻⢏⡻⡙⠃⡄⢃⠂⡄⢻⣿⣿⣿⣿⣿⣿⢏⠰⢁⠢⡘⠔⣈⢆⢡⠂⡜⠠⢌⠡⢒⠈⠤⡁⠒⡠⠑⡌⢢⢉⠒⢡⠘⡤
⡜⢦⡉⢆⡱⢂⠜⣈⠒⡔⠰⣀⠋⡄⢣⠐⡉⢆⠩⡘⠤⡉⢄⠢⢌⠱⡈⢆⠡⡔⠹⣿⣿⣿⣿⣿⣷⡌⣘⠢⡑⢬⡘⢤⢊⠦⡙⢤⠣⢌⠆⡩⢘⠤⡁⢇⠰⢡⠘⡄⢊⠜⡠⢃⠔
⢼⢣⡜⠲⣄⢣⠊⠴⢡⢊⡱⠤⡙⢢⢅⡚⠰⡌⢆⡑⢆⡉⢆⡱⢊⡔⢱⣨⣑⣮⣿⣿⣿⣿⣿⡿⣯⡻⣄⠧⡙⢴⡘⢦⡩⢒⡍⢆⡓⡌⢎⠥⢃⡒⡡⢊⢒⡡⢎⡰⢡⢊⡔⢡⢊
⢮⣓⠾⣑⢆⢣⡙⡜⢢⡑⠦⡱⢌⡣⢜⡐⣣⣜⣢⣼⣦⣭⣦⣦⣧⣾⣿⣿⣿⣿⣿⣿⣧⣿⣿⣷⣿⣿⣾⣿⣿⣦⣽⣦⣭⣷⣘⣦⡱⡜⡪⡜⣡⢎⡱⢌⡒⡔⢢⢅⠣⢆⡜⢢⢣
⣞⠼⣹⡜⡜⢦⡙⣌⢣⡙⢦⣹⢶⣷⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣟⣷⣛⣴⡊⣔⠣⡜⡌⡇⢎⠳⡌⡜⣡⢎
⡺⢯⣱⡚⣜⢣⡝⣢⢧⡙⢦⠧⢇⠈⠉⠉⠙⠉⠋⢉⢻⡟⠟⡛⠛⠛⢛⠛⢛⡛⠿⠟⠟⠿⠿⠛⠛⠩⠫⠙⠋⡉⠉⢉⡩⢉⣿⠙⠛⠉⠉⣽⢶⣙⢦⡛⡴⢣⡝⣪⢕⢪⡜⣡⢎
⡽⣛⣶⣹⣬⣳⣼⣱⣾⣿⣿⣿⣿⣿⣶⣶⣾⣴⣶⣴⣶⣿⣶⣶⣶⣶⣶⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣶⣤⣶⣦⣾⣿⣿⣶⣶⣶⣿⣿⣿⣿⣿⣿⣾⣵⡮⣵⣎⣷⣸⣇⣞
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣾⣿⣽⣿⣿⣿⣿⣿
⣿⢻⣿⠿⣟⢻⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⢿⣻⣽⢾⡽


You went to the forest with huge trees. What can you expect? Are you scared or excited?""")
            forest_1()
            chances = 0
            
        #if their choice doesn't the possibile answers and they have more than 0 chances - they will be prompted to choose direction
        else:
            chances -= 1
            if chances > 0:
                print("Please try again. Choose the direction from the list.\n")
            
            #if they have 0 chances - they will go to the villagers and fail  
            else:
                chances = 0
                print("""
You are gladly rolling to villagers. You are happy and smiling, but they don't know you and see you as a tasty bun. 
So they grab you and eat with salt (In Russian tradition to eat Bread/Bun with salt).""")
                fail()
                
                
    #mandatory stage_2 - Forest (Bear)
def forest_1():
    
    #list with lines for Kolobok's song
    kolobok_song = ["I'm Kolobok, Kolobok!","I was scraped from the flour-tin,","Swept from the corn-bin,","Mixed with sour cream into a bun","Fried in butter till I was done,","I ran away from grandpa and grandma too,","And I'm sure I'll have no trouble, running away from you."]

    print("""
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⣤⣤⣤⣀⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣶⡿⠛⠋⠉⠙⠛⠿⣷⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣿⠋⠀⠀⠀⣴⡗⠀⠀⠘⣿⡆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣸⣿⣤⣤⣶⣾⣿⣦⣤⣄⣀⣹⡿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣠⣴⡿⠟⠛⠉⠉⠁⠀⠀⠉⠉⠛⠻⠿⣿⣦⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣴⡿⠟⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠙⢿⣷⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣴⡿⠋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⡀⠀⠀⠀⠀⠙⢿⣧⡀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⡿⠋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢾⣿⣿⣷⣤⡀⠀⠀⠈⢿⣷⡀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⢠⣾⠟⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣿⣿⣿⣷⡄⠀⠀⠈⣿⣧⠀⠀⠀⠀⠀⠀
⠀⠀⠀⣠⣴⣶⣶⣶⣿⠏⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⢿⣿⠇⠀⠀⠀⢸⣿⠀⠀⠀⠀⠀⠀
⠀⢠⣾⠟⠋⠀⠀⣿⡏⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣴⣶⠿⢿⣶⣦⡀⠀⠀⠀⠀⠀⠀⠀⢸⣿⠀⠀⠀⠀⠀⠀
⢀⣿⠏⠀⠀⠀⣸⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣴⣿⠟⠉⠀⠀⠀⠈⢻⣿⡀⠀⠀⠀⠀⠀⢀⣿⡏⠀⠀⠀⠀⠀⠀
⢸⣿⠀⢠⣶⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣾⠟⣡⣶⠄⠀⠀⠀⠀⢰⣿⠃⠀⠀⠀⠀⢀⣾⡟⠀⠀⠀⠀⠀⠀⠀
⠸⣿⡄⠈⠉⠀⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⣿⠃⠀⠛⠋⠀⠀⠀⠀⣠⣿⡏⠀⠀⠀⠀⢀⣾⣿⣷⡄⠀⠀⠀⠀⠀⠀
⠀⠹⣿⣄⡀⠀⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⢀⣿⡇⠀⠀⠀⠀⠀⠀⢠⣾⣿⣿⠀⠀⠀⠀⣠⣿⠟⠀⠹⣿⣆⠀⠀⠀⠀⠀
⠀⠀⠈⠛⠿⠿⣿⣷⠀⠀⠀⢀⣤⣤⡀⠀⠀⢿⣧⡀⠀⠀⠀⣠⣴⣿⣿⣿⡿⠀⠀⣠⣾⠟⣁⠀⠀⠀⠹⣿⣆⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠘⣿⡆⠀⠀⠘⣿⣿⣿⣦⡀⠈⠻⢿⣷⣶⡿⣿⣿⣿⣿⣷⣧⣠⣾⡿⠋⠀⣿⣇⠀⠀⠀⠘⣿⣆⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠹⣿⣄⠀⠀⠈⠿⣿⣿⣿⡆⠀⠀⠀⠀⠀⣿⢿⣿⣀⣤⣾⠟⠁⠀⠀⠀⢸⣿⠀⠀⠀⠀⠀⠹⣿⡄⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠘⢿⣧⣀⠀⠀⠈⠛⠛⠁⠀⠀⠀⠀⠀⢀⣸⣿⣿⡟⠁⠀⢠⣶⣦⣤⣸⣿⠀⠀⠀⠀⠀⢿⣷⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠙⢿⣷⣤⣀⡀⠀⠀⠀⢀⣀⣤⣶⣿⡿⠉⣿⢇⢰⣾⣿⣿⣿⣿⢸⣿⠀⠀⠀⠀⠘⣿⡆⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠙⠛⠿⠿⠿⠿⠿⠛⠋⢩⣿⠇⢸⣿⠙⠻⣿⣿⡿⠿⣷⣼⣿⠀⠀⠀⠀⢿⣧⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣼⡟⠀⣸⡿⠀⠀⠺⠟⠋⠀⠉⣸⡟⠀⠀⠀⠀⠀⠀⢸⣿⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⣿⠃⠀⣿⡇⠀⠀⠀⠀⠀⠀⠀⣿⡇⠀⠀⠀⠀⠀⠀⢸⣿⡆
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣾⡏⠀⢠⣿⠃⠀⠀⠀⠀⠀⠀⠀⢿⣧⠀⠀⠀⠀⠀⠀⢸⣿⠃
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⣿⠃⠀⣸⡿⠀⠀⠀⠀⠀⠀⠀⠀⣸⣿⣆⠀⠀⠀⠀⠀⣼⣿⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢺⣿⠀⢀⣿⡇⠀⠀⠀⠀⠀⠀⠀⠠⣿⣯⣿⣿⣶⣦⣶⣿⢿⣿⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⣿⣧⣼⣿⠀⠀⠀⠀⠀⢀⡀⠀⠀⠻⣿⣿⣿⣷⣾⣿⣿⣿⡟⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⣿⣿⣿⡇⠀⠀⠀⠀⠀⢸⣿⣿⣧⠀⠈⠉⠹⣿⣿⣿⡏⠉⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠙⢿⣿⠃⠀⠀⠀⠀⠀⢸⣿⢸⣿⠀⠀⠀⠀⠀⠀⣿⡇⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⠀⠀⠀⠀⠀⠀⢸⣿⣼⣿⠀⠀⠀⠀⠀⠀⢻⣧⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⠀⠀⠀⠀⠀⠀⠘⣿⣿⣿⠀⠀⠀⠀⠀⠀⢸⣿⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⡀⠀⠀⠀⠀⠀⢠⣿⢿⣿⠀⠀⠀⠀⠀⠀⣸⣿⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠻⣿⣶⣦⣤⣴⣶⣿⠟⠈⢿⣷⣦⣤⣤⣴⣾⡿⠃⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠉⠉⠉⠁⠀⠀⠀⠀⠈⠉⠉⠉⠉⠁⠀⠀⠀⠀⠀


You are in the forest and you meet a Big Hungry Bear. What is his name?""")
    
    #giving 3 chances
    chances = 3
    
    #while chances are above 0 AND input is not empty - user will be prompted to choose a name
    while True and chances > 0:
        bear_name = input(prompt = 
"""
Choose the name of the Big Hungry Bear:\n""").title().strip()
        chances -= 1
        
        #if input is empty - and there are more than 0 chances - loop will restart
        if not bear_name and chances > 0:
            print("It can not be empty space. Try again\n")
            
        #if input is not empty
        else:
            
            #and chances are 0 - bear_name will be "Mishka"
            if chances == 0:
                bear_name = "Mishka"
                print(f"""
We chose his name for you:
{bear_name} sees you and says: Oh, little Kolobok, I will eat you now.\n""")
                
            #if user puts a name - it will be chosen and set and loop stops
            else:
                print(f"{bear_name} sees you and says: Oh, little Kolobok, I will eat you now.\n")
                chances = 0
                break
            
    print("""
─═──═──═──═──═──═──═──═──═──═─୧⍤⃝─═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──

What will you say or do?
1. Respond: Fine =(
2. Try rolling away.
3. Respond: Don't eat me! I will sing you a song!""")

    choice_4 = input(prompt = "-> ").casefold()
    
    #if user's choice is mentioned below - they will fail the stage
    if choice_4 == "1" or choice_4 == "1." or "respond: fine" in choice_4 or "fine" in choice_4 or "=(" in choice_4:
        print(f"You say that you are fine with being eaten, so {bear_name} ate you in one bite, and said: You were delicious, Kolobok!\n")
        fail()
    
    #if user's choice is mentioned below - they will fail the stage
    elif choice_4 == "2" or choice_4 == "2." or "try rolling away" in choice_4 or "try" in choice_4 or "roll" in choice_4 or "away" in choice_4:
        print(f"You tried rolling away and {bear_name} caught you immediately, ate you in one bite, and said: This was a delicious bun!\n")
        fail()
        
    #if user's choice is mentioned below - they will see Kolobok's song and move to the next part   
    elif choice_4 == "3" or choice_4 == "3." or "don't eat me! i will sing you a song" in choice_4 or "don't" in choice_4 or "sing" in choice_4 or "song" in choice_4:
        
        #will print every line from the list one by one
        for line in kolobok_song:
            print(line)
            time.sleep(1) #one line per second 
            
        print(f"""
{bear_name} listened to your lovely song and didn't notice how you rolled away!

Now, you escaped {bear_name}, it's becoming darker and you hear crows...\n""")
        forest_2()        
    
    #otherwise user will be prompted to retry the stage or exit  
    else:
        print(
"""
There is no such answer :\ Try Again?
> Yes
> Exit""")
        try_again = input(prompt = "-> ").casefold()
        
        if "yes" in try_again or try_again == "1":
            forest_1()
        else:
            fail()                


    #mandatory stage_2 continued - Forest (Direction Choice) 
def forest_2():
    print("""
─═──═──═──═──═──═──═──═──═──═──═──═──═─୧⍤⃝─═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──

So choose where to go next:
[Choose one option]

1. To the left, where you hear water sounds.
2. To the right, deeper into the Green Forest.""")
    
    #giving 3 chances
    chances = 3
    
    #loop will happen while there are more than 0 chances
    while chances > 0:
        choice_5 = input(prompt = "-> ").casefold()

        #optional stage_4 - River
        #if user's choice is mentioned below - they will go to the River stage
        if choice_5 == "1" or choice_5 == "1." or "to the left, where you hear water sounds" in choice_5 or "left" in choice_5 or "water" in choice_5 or "sound" in choice_5:
            chances = 0
            print("""
⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠿⠿⠿⠿⢿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⠿⠛⠋⠉⠉⠉⠙⠛⠿⣿⣿⣿⠟⠋⠀⠀⠀⠀⠀⠀⠀⠀⠉⠻⢿⣿⣿
⣿⠋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣸⠟⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠙⣿
⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣰⡏⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿
⣿⠀⠀⣀⣀⣀⣀⣠⣤⣤⣤⣿⣤⣤⣤⣤⣤⣤⣤⣄⣀⣀⣀⣀⣀⣀⣀⣀⣀⣿
⣿⣿⣿⣿⣿⣿⣿⡟⠛⠉⠉⠉⣴⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣦⣄⡀⠀⠀⠉⠉⠙⠛⠻⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⠿⠿⠿⠛⠛⠛⠂⠀⠀⠀⠀⢀⣸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⠛⠉⠀⠀⠀⠀⠀⠀⠀⢀⣤⣤⣴⣶⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣦⣤⣀⡀⠐⠒⠢⢤⣄⡀⠀⠀⠈⠉⠉⠙⠛⠛⠻⢿⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣶⣦⣤⣀⡉⠁⠀⠀⠀⠀⠀⠀⠀⢀⠀⠈⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠿⠛⠁⠀⠀⡀⠀⠀⡠⠞⠃⠀⣠⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣿⠟⠉⠀⠀⠀⣠⠞⠁⠀⠀⠀⠀⢀⣴⣾⣿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⡏⠀⠀⣆⠀⠀⠻⣄⠀⠀⠀⣄⠀⠀⠙⠻⠿⣿⣿⣿⣿⣿⣿⣿
⣿⣿⣿⣿⣿⣿⣧⣤⣤⣬⣷⣤⣤⣤⣵⣤⣤⣬⣿⣦⣤⣤⣤⣤⣬⣭⣿⣿⣿⣿


You went towards the sound of water and found a river.""")
        
            print("""
    Do you want to swim? [Choose one option]
    1. Yes!
    2. No! Let's go back to the forest path!""")

            swim = input(prompt = "-> ").casefold()
            
            #if user's choice is mentioned below - Kolobok will fail  
            if swim == "1" or swim == "1." "yes" in swim:
                print("You jump to the blue river and after a few second you dissolve in water.")
                fail()
            
            #if user's choice is mentioned below - they will go back to the Forest stage
            elif swim == "2" or swim == "2." or "no" in swim or "let's go back" in swim or "back" in swim or "forest" in swim or "path" in swim:
                print("You realize that you would drown, as you are just a bun, so you return to the Green Forest.")
                forest_3()
            
            #otherwise they will be prompted to replay the forest_2 part
            else:
                print(
"""
There is no such answer :\ Try Again?
> Yes
> Exit""")

                try_again = input(prompt = "-> ").casefold()

                if "yes" in try_again or try_again == "1":
                    forest_2()
                else:
                    fail()
        #if user's choice is mentioned below - they will go to further into the forest
        elif choice_5 == "2" or choice_5 == "2." or "to the right, deeper into the Green Forest" in choice_5 or "right" in choice_5 or "deeper" in choice_5 or "green" in choice_5 or "forest" in choice_5:
            chances = 0
            print("""
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⢀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⢀⠀⣠⡾⠿⠹⠟⣲⡿⣦⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣤⡾⠛⣿⠇⠩⣘⡟⣀⢀⠛⠀⠉⢉⡽⠦⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣤⣴⣿⣟⣛⣷⣾⣤⣦⡴⣿⣽⣴⣾⣤⣤⣵⣮⣛⡂⠀⠀⠀⠀⠀⠀⣀⢀⡀⠀⠀⠀⠀⠀⠀⠀⠤⢼⠏
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠚⣿⣿⣿⣿⣿⣿⣿⣿⣷⣿⣷⣼⢻⠛⣿⣿⡟⣿⣦⢰⣵⣯⣤⣤⠀⠀⠈⠛⠋⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⢀⠀⠀⠀⠀⠀⠀⠀⠀⣈⣀⠝⣽⠝⠋⢰⡿⣿⣿⣦⣏⣷⣿⡞⠋⠈⠀⠌⠐⡖⠁⢰⠻⠽⣤⡀⠀⠀⠀⠀⠀⠀⢀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠈⠻⠁⠀⠀⠀⣠⣶⣾⣯⠹⡦⠑⡆⠀⣀⠐⠛⣿⢿⢇⣽⣿⣿⣶⣾⠀⢀⣬⣇⣆⣀⡀⣶⣳⡆⠀⠀⠀⠀⠀⠐⠿⠁⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣼⣿⣿⣿⣶⡰⢶⣦⢀⣤⣈⣀⠉⣾⡏⠿⣿⢯⣿⣿⣿⡟⠙⢀⡟⠛⠿⣷⣿⣿⣿⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⡻⣻⣿⣿⣿⣤⣿⣿⣾⣹⣿⣿⢟⠻⠿⠀⠟⢀⡀⣸⣯⡄⠲⠀⠀⠀⡐⢉⠙⣻⣿⣿⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⡀⠀⠐⠻⠿⣟⣻⣿⣧⢯⣽⣿⢫⣶⡾⢿⡧⣠⣮⡴⣽⣿⣋⣁⠔⠉⠣⢨⠣⣲⡿⢿⠿⠟⠃⠀⠀⠀⠀⠀⣀⣤⠀⠀⠀⠀⠀
⣦⡄⠀⠀⠀⠀⠠⣾⣿⣷⣿⣶⣶⣿⣿⢊⠹⠉⣻⡿⣭⣿⠷⠀⣻⣷⣮⣾⠿⣟⡿⢿⣶⣺⣤⣠⣷⣷⣿⣦⣿⠇⣲⣶⣄⠀⠀⠀⠈⠃⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⢨⣿⣿⢿⣿⣿⣟⣙⣩⣯⣿⣿⣿⣿⣧⣿⣶⣿⣿⠿⠙⠈⠚⠀⢀⠀⠉⢟⠻⣍⠋⠐⡉⠉⠁⠄⢙⡟⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠐⠻⠻⢻⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣶⣬⣴⠠⠐⣀⣠⡙⣿⡶⠚⡄⣸⢋⡀⠄⠀⢌⢡⣿⡥⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠐⠿⢿⠿⣿⣿⣿⣿⣿⣿⣟⣽⣿⣿⣯⣻⣿⣿⣿⣿⣿⣾⣿⣿⣿⣿⣿⣿⣿⣰⣬⣿⣿⣤⣐⣍⣻⡾⠅⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠀⠙⠉⢻⣿⣿⣿⣻⣿⣿⣿⣿⣿⣿⢻⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡟⠛⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⢸⠟⣿⣿⣿⣿⣿⣿⣿⠿⠻⠿⢻⣿⣿⡆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠙⠛⢩⢿⡟⠻⠛⠃⠛⠟⠃⠘⣿⣏⡗⣴⡿⠁⠀⠛⠛⡟⠟⠀⠀⠀⠀⠙⠛⠛⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠁⠀⠀⠀⠀⠀⠀⢀⣿⡯⣯⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⡗⣧⡏⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣹⣿⣿⢿⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣿⣿⣿⣼⢿⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⢀⣀⣦⣾⣶⣶⣶⣿⣿⣿⣿⢿⢸⠾⣿⣶⣶⣷⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣤⣠⣴⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣗⣿⡟⣷⢹⣿⣿⣿⣿⣿⣧⣦⣤⣄⣀⡀⢀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⢀⠀⣄⣿⣀⣀⣸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⣟⣿⣿⡿⣿⣿⣟⡿⠄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⢠⢦⣦⣿⡿⠿⡿⠿⣿⣿⣿⡿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠫⣷⣿⣾⣿⣿⣿⣧⣦⣦⣿⣦⣶⣀⣄⡀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠉⢰⣤⣍⠛⣉⡙⠻⠿⠞⢛⣦⣧⣭⣴⣾⣿⣿⣿⣿⣿⣾⣿⣿⣿⣏⣽⡉⠻⠟⠿⣭⣾⣿⣧⡜⠛⠛⠻⣯⠤⠏⠀⠃⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠙⠟⠈⠀⠉⠃⠀⠀⠀⠀⠀⠘⢮⡿⠟⠛⠛⢿⣿⣿⡿⡛⡿⠿⠄⠉⠁⠀⠀⠺⠟⠏⠁⠈⠁⠐⠛⠓⠚⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠙⠂⠉⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀


You went further into the Green Forest.""")
            forest_3()
        #if user can't decide - and they have more than 0 chances - they will be prompted to retry their entry
        else:
            chances -= 1
            if chances > 0:
                print(
"""
There is no such answer :\ Try Again.""")
            
            #if they don't have chances left - they will go to the forest
            else:
                chances = 0
                print("You remembered that water can be dangerous for you and went further into the Green Forest.")
                forest_3()
            
    #mandatory stage_2 continued - Forest (Wolf)       
def forest_3():
    
    #creating a list of possible wolf names
    wolf_names = ["Seriy", "Vasya", "Klik"]
    
    #randomly selecting one name out of that list
    random_wolf_name = random.choice(wolf_names)
    print(f"""
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣤⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣰⠻⣥⠙⢦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⡿⠀⡿⠻⣆⠙⠦⣤⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢿⡄⠁⠀⠘⣆⡔⢶⣆⠉⢷⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢻⡄⠀⠀⡿⢿⡀⠉⠀⠞⠹⡆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⡿⡄⠀⡇⠘⣧⣀⣀⣀⠀⠻⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣼⠃⠁⢀⣠⠞⣹⢿⠻⡟⢿⣿⣯⢳⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣾⠃⠶⠒⠉⠁⣴⠇⢸⡇⡟⡷⢬⡙⠎⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⣿⠇⢀⣠⣄⡀⠚⠁⠀⠈⠀⠀⣷⠀⠉⠛⠛⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⡼⣽⣿⣶⠋⢉⡿⠇⠀⠀⠀⠀⠀⣰⣿⣇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⢱⣿⣿⠇⠀⣠⣥⣤⡀⠀⠀⠀⢀⡟⣿⣿⣦⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⣼⢿⣿⢀⣾⡟⠉⢹⡇⠀⠀⠀⢸⠁⡿⠙⣿⣷⣄⡀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠸⢸⣇⣾⡟⠀⠸⡏⣄⡀⠀⠀⢹⢀⡇⢀⢘⢿⣮⡙⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⣿⣿⣇⠀⡀⣧⠰⣿⣶⣄⠀⠀⠀⠘⣎⠳⣿⣿⣦⡀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠸⡿⣿⣆⠹⣿⡐⣾⣷⣹⣆⠀⠀⠀⠘⢷⣄⣻⣿⣿⣷⡄⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠹⢿⣿⣦⠽⣇⣹⣟⢿⠙⠁⠀⠀⠀⣤⠉⠻⣿⣿⣿⣿⣦⡀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠙⡟⠂⣿⢹⡿⣼⠇⠀⠀⣀⠀⣷⡀⠀⠈⠻⣿⣿⣿⣷⡀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⡆⢻⠀⠉⢸⡇⠈⣀⣠⣾⠇⠀⠻⣿⣦⣤⣴⣿⠿⣿⡿⣷⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⡇⢸⡀⠀⢸⠁⣰⠛⣽⡧⠖⠻⢿⡆⠈⠉⠉⠀⠀⢻⣷⠹⠇
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⠘⡇⠀⢸⢰⡏⢰⡟⠀⣀⣀⡼⠃⠀⢀⡆⠀⠀⠘⣿⡆⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣠⣤⣴⣿⣶⣷⣶⣾⣿⣧⣾⣤⣄⣀⣀⣤⣤⣶⡿⠀⠀⠀⢠⣿⡇⠀
⠀⠀⠀⠀⠀⠀⠀⣠⣴⣾⣿⣟⡛⠛⠛⠉⠉⠉⠉⢉⣭⣽⡿⠿⠿⠿⠛⠛⠛⠓⠲⠦⠄⣼⢻⡇⠀
⠀⠀⠀⠀⠀⠀⠘⢉⣼⣿⣿⠿⠛⠛⠁⠀⠀⣠⠖⠋⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠸⠁⣸⡇⠀
⠀⠀⠀⠀⠀⢀⣴⠿⠛⠁⢀⣀⣀⣀⣀⣀⣄⡀⠀⠀⠀⢦⣀⠀⠀⠀⠀⠀⠀⠀⠀⣠⠇⣰⣿⠁⠀
⠀⠀⠀⢀⣴⣟⣥⣶⣾⣿⣿⣿⣿⣿⣿⣭⣤⣤⣤⣀⣀⡀⠈⠛⠶⢶⣶⣶⣶⣾⣿⣿⣿⠟⠁⠀⠀
⠀⢀⣴⡿⠟⠋⡽⠟⠉⠉⠀⠀⠀⠀⠀⠀⠀⠈⠉⠉⠉⠙⠛⠛⠛⠿⠿⠿⠿⠟⠛⠉⠁⠀⠀⠀⠀
⠐⠋⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀


You meet a big and hungry gray wolf. He is known as {random_wolf_name}. 
He says: I am so hungry, so I will snack with you, Kolobok!""")
    
    print("""
What do you plan to do now? [Choose one option]
1. Respond: I want to be friends!
2. Point at birds and try rolling away.
3. Respond: Don't eat me! I will sing you a song!\n""")
    
    choice_6 = input(prompt = "-> ").casefold()
    
    #creating a nested conditional statement
    if choice_6 == "1" or choice_6 == "1." or "i want to be friends" in choice_6 or "friends" in choice_6:
        
        #if the wolf name is Seriy then user fails
        if random_wolf_name == "Seriy":
            print("Seriy is a mean wolf, so he doesn't want to be friends and eats you.")
            fail()
        
        #if the wolf name is Vasya then user fails
        elif random_wolf_name == "Vasya":
            print("Vasya could be your friend, but he is very hungry, so he snacks with you.")
            fail()
        
        #if the wolf name is Klick then user has 50% chance of passing or failing
        elif random_wolf_name == "Klik":
            print("There is a chance Klik will be your friend.")
            chance = random.choice([1,2])
            
            #if random chance (between numbers 1 and 2) is 1 then user passed
            if chance == 1:
                print("You are lucky! Klik will be your friend, so you can go ahead!.")
                forest_4()
                
            #if that chance is 2 then user fails
            elif chance == 2:
                print("Today is not your day. He is unfriendly and he wants a tasty bun. So Klik eats you.")
                fail()
            
            #otherwise Try Again menu will pop up
            else:
                print("""
There is no such answer :\ Try Again?
> Yes
> Exit""")
        
                try_again = input(prompt = "-> ").casefold()
        
                if "yes" in try_again or try_again == "1":
                    forest_3()
                else:
                    fail()
        else:
            print("""
There is no such answer :\ Try Again?
> Yes
> Exit""")
        
            try_again = input(prompt = "-> ").casefold()
        
            if "yes" in try_again or try_again == "1":
                forest_3()
            else:
                fail()
    
    #if the choice is below then there is a 50% chance user will pass
    elif choice_6 == "2" or choice_6 == "2." or "point at birds" in choice_6 or "try rolling away" in choice_6 or "birds" in choice_6 or "roll" in choice_6 or "away" in choice_6:
        chance_1 = random.choice([1,2])
        
        #if the chance_1 is 1 then user passes
        if chance_1 == 1:
            print("He got distracted while you quickly rolled away.")
            forest_4()
        
        #if the chance_1 is 2 then user fails
        elif chance_1 == 2:
            print(f"He was smarter than you thought. {random_wolf_name} saw you, and reached you faster than you could blink. And he ate you.")
            fail()
        
        #otherwise a Try Again menu will pop up
        else:
            print("""
There is no such answer :\ Try Again?
> Yes
> Exit""")
        
            try_again = input(prompt = "-> ").casefold()
        
            if "yes" in try_again or try_again == "1":
                forest_3()
            else:
                fail()
    
    #and if there is a 3rd choice - below - then the following statement will be printed and users goes further
    elif choice_6 == "3" or choice_6 == "3." or "don't eat me! i will sing you a song" in choice_6 or "don't" in choice_6 or "sing" in choice_6 or "song" in choice_6:
        print(f"""
You say that you will sing a song and sing it to {random_wolf_name}, adding that you ran away from the Big Bear too.
Gray Wolf liked your singing and didn't notice how you escaped.""")
        
        forest_4() 
    
    #otherwise a Try Again menu pops up
    else:
        print("""
There is no such answer :\ Try Again?
> Yes
> Exit""")    
        
        try_again = input(prompt = "-> ").casefold()
        
        if "yes" in try_again or try_again == "1":
            forest_3()
        else:
            fail()
    
    
    #Mandatory stage_2 continued - Forest (Rabbit)  
def forest_4():
    print("""
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⠠⠔⠒⠚⠒⠦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⠔⠉⠁⠀⠀⠀⠀⠀⠀⠘⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⠀⣀⡀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡴⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡠⠔⠊⠁⠀⠀⠀⠈⠑⡄
⠀⠀⢀⣀⡀⠀⠀⠀⠀⠀⠸⡏⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⠆⠈⣇⠀⠀⠀⠀⠀⠀⢀⠔⠋⠀⠀⣀⠤⠤⡄⠀⠀⠀⢸
⢸⡉⠻⢠⠇⠀⠀⠀⠀⠀⠀⠙⠦⣀⣀⣀⣀⣠⡤⣶⡏⢹⠀⣀⣹⠀⠀⠀⠀⢀⡔⠁⠀⣠⠔⠉⠀⠀⠀⡅⠀⠀⢠⡏
⠀⠉⠒⠋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⡠⠖⠻⠁⠀⠀⠀⠈⠉⠁⠒⡤⠋⠀⣠⠖⠁⠀⠀⠀⣠⠊⠀⢀⠔⠋⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⠔⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠁⠀⢾⠁⠀⢀⡠⠔⠊⠀⣠⠔⠉⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⠋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠙⠚⠁⠀⣠⠔⠋⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⡴⠋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠐⠚⢻⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⡞⠀⡀⢢⣼⣿⡆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣾⠁⠀⠀⠀⢹⡟⠀⢰⣶⠀⠀⣠⣶⣤⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢹⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢻⡆⠀⠀⠀⠀⠀⠀⠀⠉⠀⠀⠻⠿⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣼⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢻⣦⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⠃⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠻⢦⢄⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⠏⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⡤⠤⠭⠵⠦⠤⢄⡀⠀⠀⠀⠠⣀⠀⠀⠀⠀⣀⠴⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢿⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢳⠒⠒⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠁⠘⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⡤⠤⢼⡀⠀⠀⠀⠀⠀⠀⠀⢀⣀⣵⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠻⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⠋⠀⠀⢱⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠉⠒⠒⠢⠤⠤⣀⣀⣀⣘⣇⣀⣀⠾⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠁⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀

You meet a Rabbit on the way. His name is Beliy.
Beliy can't let such appetizing bun to roll away! He says: 
I didn't have any food today, but here you rolled to me!\n""") 
    
    print("""
What are you going to do?! [Choose one option]
1. Tell him: Let's be friends!
2. Try fighting Beliy.
3. Respond: Don't eat me! I will sing you a song!""")
    
    #prompting user to choose
    choice_7 = input(prompt = "-> ").casefold()
    
    #if choice is below then user goes further
    if choice_7 == "1" or choice_7 == "1." or "tell hime: let's be friends" in choice_7 or "friends" in choice_7:
        print("""
Beliy is your friend now!
He gives you a hug and disappears in the forest.""")
        forest_5()
    
    #if choice is below then user fails 
    elif choice_7 == "2" or choice_7 == "2." or "try fighting beliy" in choice_7 or "fight" in choice_7:
        print("""
Beliy is faster and has teeth and limbs, unlike you!
So fighting wasn't the best idea. He becomes angry and takes you to the forest for a lunch with his family.""")
        fail()
    
    #if choice is below - user goes further
    elif choice_7 == "3" or choice_7 == "3." or "don't eat me" in choice_7 or "sing" in choice_7 or "song" in choice_7:
        print("""
You say that you will sing a song and sing it to Beliy, adding that you ran away from Big Bear and Gray Wolf, too.

Meanwhile, you started rolling away and the Rabbit enjoyed the song so much, that he lost you out of sight!""")
        forest_5()
    
    #otherwise a Try Again menu pops up    
    else:
        print("""
There is no such answer :\ Try Again?
> Yes
> Exit""")  
        
        try_again = input(prompt = "-> ").casefold()
        
        if "yes" in try_again or try_again == "1":
            forest_4()
        else:
            fail()
             
        
    #Mandatory stage_3 - Dark Forest at Night (Fox)      
def forest_5():
    print("""
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣶⣾⣿⡷⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣿⣿⣿⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣴⣿⣿⠁⢿⣿⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⣿⣿⣿⣇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⠁⠀⠈⣿⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠻⣿⡿⣿⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⡏⠀⠀⠀⢿⣿⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣴⣿⣿⠀⠀⠀⠀
⠀⠀⠀⠀⢹⣧⠈⠙⠷⣶⣤⣀⣀⣀⣀⣠⣤⣴⣶⣶⣾⣿⣿⣷⣶⣶⣜⡋⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣤⣤⣤⣾⣿⣿⠿⠀⠀⠀⠀
⠀⠀⠀⠀⠀⢿⣇⠀⠀⠈⠉⠉⠉⢋⣉⣉⣉⠉⠉⠉⠁⠀⠉⠉⠙⠛⢿⣿⣦⡀⠀⠀⣀⣴⣶⣿⠿⠟⣻⣿⣿⣿⡿⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⢿⣆⠀⠀⠀⠀⠀⠀⠉⠙⠛⠛⠛⠛⠻⠶⣦⣤⣄⡀⠀⠉⠻⣷⣠⣾⠟⠋⢁⣤⣶⡿⠟⢛⣿⣿⠃⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠘⣿⣆⠀⠀⠀⠀⠀⠀⠘⢶⣶⠶⠶⠶⣶⣤⣬⡛⢿⣦⡀⠀⠈⠋⢀⣴⣾⡿⠛⠁⠀⢀⣼⡿⠋⠀⠀⠀⣄⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠹⣿⣷⣤⣀⠀⠀⠀⠀⠀⠻⣦⣀⣰⣿⣿⣿⣿⠀⢹⣷⠀⠀⠀⢸⡿⠁⠀⠀⠀⣰⣿⡿⠁⠀⠀⠀⣰⣿⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠹⣧⠉⠛⠷⢶⣤⣴⡇⠀⠈⠙⠿⢿⡿⠿⠛⣀⣾⡟⠀⠀⠀⠈⠁⠀⢀⣰⣾⠿⠋⠀⠀⠀⠀⣰⣿⣿⡀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠹⣇⠀⠀⠀⠀⢻⣇⠀⠀⠀⠀⠀⠰⢶⣿⣛⡋⠀⠀⠀⠀⠀⣠⣴⡿⠟⠁⠀⠀⠀⠀⣀⣾⣿⣿⣿⣇⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠹⣇⠀⠀⠀⠈⢿⣆⠀⠀⠀⠀⠙⣾⣿⣛⠛⠀⠀⠀⣠⡾⠟⠁⠀⠀⠀⠀⠀⢀⣴⣿⣿⣿⣿⣿⣿⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢹⣇⠀⠀⠀⠈⠻⢷⣤⣍⣻⣿⣿⠙⠁⠀⠀⢠⡾⠋⠀⠀⠀⠀⠀⠀⢀⣴⣿⣿⣿⣿⣿⣿⣿⣿⡄⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢻⣇⠀⠀⠀⠀⠀⠈⠉⠉⠀⠀⠀⠀⠀⠀⣿⣇⠀⠀⠀⠀⠀⢀⣴⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢿⡆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠴⣿⠏⠀⠀⠀⢀⡴⣿⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⣿⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢴⡶⠛⠁⠀⢀⡰⠏⢞⡽⣾⣇⡟⣹⠟⣿⣿⣿⣿⣿⣿⣿⡀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣸⡿⠁⠀⠀⠀⠀⠀⣠⣶⡶⠶⠒⠚⠋⠀⠀⢀⡾⠃⠀⠈⡷⢰⡟⢷⣟⣜⣁⠿⢉⠟⣿⢿⣿⡇
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣾⠟⠀⠀⠀⠀⠀⠀⢀⡟⠀⠀⠀⠀⠀⠀⠀⢠⡾⠁⠀⠀⠀⠀⠘⠓⣶⢿⣽⠉⢶⡎⠀⠛⠀⣿⡇
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⡞⠃⠀⠀⠀⠀⠀⠀⠀⢸⠁⠀⠀⠀⠀⠀⠀⠀⡾⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠺⠏⠹⠛⡋⠶⣿⡇
⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⣏⡀⠀⠀⠀⠀⠀⠀⠀⠀⣿⠀⠀⠀⠀⠀⠀⠀⣸⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠁⢠⣿⡇
⠀⠀⠀⠀⠀⠀⠀⠀⢀⣼⠋⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⠀⠀⠀⠀⠀⠀⠀⡟⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⠀
⠀⠀⠀⠀⠀⠀⠀⢀⡾⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⡇⠀⠀⠀⠀⠀⢰⠇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣿⠃⠀
⠀⠀⠀⠀⠀⠀⠀⠿⣷⡶⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⠀⠀⠀⠀⠀⢸⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣾⡟⠀⠀
⠀⠀⠀⠀⠀⠀⠀⣠⡞⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢿⣇⠀⠀⠀⠀⢸⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣼⡿⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠘⣿⡗⠂⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⣿⡀⠀⠀⠀⢸⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣰⡿⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠰⣿⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠹⣷⠀⠀⠀⠘⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⡿⠁⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⣿⡀⠀⠀⠀⠰⣼⡀⠀⠀⠀⠀⠀⠀⠀⠀⢻⣆⠀⠀⠀⣷⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣿⠁⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠈⠻⣦⣀⠀⠀⣯⣹⠆⠀⠀⠀⠀⠀⠀⠀⠀⢿⡄⠀⠀⢿⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣿⠁⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⡟⢧⣤⣞⡉⢇⠀⡄⠀⠀⠀⠀⠀⠀⠀⢿⡄⠀⠸⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣾⠏⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⡇⠀⢸⣿⣧⣾⣴⣿⠀⠀⠀⠀⠀⠀⠀⠈⢿⡀⠀⢷⡀⠀⠀⠀⠀⠀⠀⠀⠀⣸⡿⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⣠⡾⠿⠟⠛⠷⠦⣼⣇⠀⢸⣿⣿⣿⣿⡿⠀⠀⠀⠀⠀⠀⠀⠀⠀⢻⡄⢸⡇⠀⠀⠀⠀⠀⠀⠀⠀⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⡟⠀⠀⠀⠀⠀⠀⠘⣿⡀⢸⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠻⣾⣿⡀⠀⠀⠀⠀⠀⠀⢸⣿⠁⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⣧⠀⠀⠀⠀⠀⠀⠀⢹⡇⢸⣿⣿⣿⣿⣧⣤⣤⣤⣀⣀⣀⠀⠀⠀⠀⠀⠈⠻⣇⠀⠀⠀⠀⠀⠀⢸⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠹⣦⠀⠀⠀⠀⠀⠀⢸⡇⢸⣿⣿⣿⡿⠛⠛⠛⠛⠛⠛⠻⢿⣶⣦⡀⠀⠀⠀⠈⢦⠀⠀⠀⠀⠀⢸⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠻⣧⡀⠀⠀⠀⠀⢸⣷⢸⣿⣿⡏⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠛⢦⣄⡀⠀⠈⢣⡀⠀⠀⠀⢸⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠙⢿⣦⠀⠀⠀⢸⣿⢸⣿⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠛⢦⡀⠈⢧⡀⠀⠀⢸⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠙⠿⣆⡀⢸⣿⠸⣿⣿⡆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠙⢦⠘⣇⠀⠀⢸⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀
⣠⣴⣶⣶⣶⣶⣶⣶⣿⣿⣿⡟⠀⣿⣿⣿⣦⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢹⡆⠀⣼⡟⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠿⣿⣿⣿⣿⡿⠿⠛⢋⣩⠟⠁⢠⣿⣿⡟⠙⢷⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣸⣷⣰⡿⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠈⠉⠉⠀⠀⠀⢶⣿⣥⣤⣶⣿⣿⣿⠇⠀⠀⠙⠳⣤⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣿⣿⠟⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠈⠙⠿⠿⠟⠛⠁⠀⠀⠀⠀⠀⠀⠈⠛⣦⣤⣀⠀⠀⠀⠀⠀⠀⢀⣴⣿⡿⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⢀⣴⣶⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⠿⠿⠛⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠈⠻⣿⣿⣿⣿⣿⠿⠟⠛⠋⠉⠉⠉⠉⠉⠉⠉⠙⠛⠛⠉⠀⠀⢀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀


It got super dark and looks like a completely new place but you are still rolling through the forest.
And you see a Red Fox. She sees you too. What do you want to do? [Choose one option]

1. Try rolling away.
2. Get closer and try to talk with her.""")
    
    #prompt user to choose
    choice_8 = input(prompt = "-> ").casefold()
    
    #if choice is below the user fails
    if choice_8 == "1" or choice_8 == "1." or "try rolling away" in choice_8 or "try" in choice_8 or "roll" in choice_8:
        print("""
She catches you and eats you fast! 
You made it so far but she was faster.""")
        fail()
    
    #if prompt is below user is prompted with another choice
    elif choice_8 == "2" or choice_8 == "2." or "close" in choice_8 or "get closer" in choice_8 or "talk" in choice_8:
        print("""
You decide to roll towards her. She greets you and asks: Where are you going? [Choose one option]
1. Just roaming around!
2. I went on an adventure! And escaped from everyone on my way!""")
        
        choice_9 = input(prompt = "-> ").casefold()
        
        #if user chooses this choice - it's a pass further
        if choice_9 == "1" or choice_9 == "1." or "just roaming around" in choice_9 or "roam" in choice_9 or "around" in choice_9:
            print("'Just Roaming Around!' Red Fox says: Kolobok, sing me a song!")
            forest_6()
        
        #if user chooses this choice - it's a pass further
        elif choice_9 == "2" or choice_9 == "2." or "went on an adventure" in choice_9 or "escaped from everyone" in choice_9 or "adventure" in choice_9 or "escape" in choice_9 or "way" in choice_9:
            print("'I went on an adventure! And escaped from everyone on my way!' Red Fox says: Kolobok, sing me a song!")
            forest_6()
            
        #otherwise a Try Again menu pops up 
        else:
            print("""
There is no such answer :\ Try Again?
> Yes
> Exit""")
            try_again = input(prompt = "-> ").casefold()
            
            #user can choose to restart the scene
            if "yes" in try_again or try_again == "1":
                forest_5()
                
            #or could exit
            else:
                fail()
    
    #otherwise user gets Try Again choice
    else:
        print("""
There is no such answer :\ Try Again?
> Yes
> Exit""")
        
        try_again = input(prompt = "-> ").casefold()
        
        #user could restart scene
        if "yes" in try_again or try_again == "1":
            forest_5()
        
        #or lose
        else:
            fail()
    
    #mandatory stage_3 continued - Dark Forest (Fox Cont.) 
def forest_6():
    print("""
─═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═─୧⍤⃝─═──═──═──═──═──═──═──═──
    
Will you sing a song? [Choose one option]
1. No! I'm rolling away! And Fast! She is too nice!
2. Definitely!""")
    
    choice_10 = input(prompt = "-> ").casefold()
    
    #if choice is below - user fails
    if choice_10 == "1" or choice_10 == "1." or "no! i'm rolling away" in choice_10 or "no" in choice_10 or "roll" in choice_10 or "fast" in choice_10 or "nice" in choice_10:
        print("You started rolling away fast and didn't notice a puddle. You started to dissolve in water and your journey finished here...")
        fail()
    
    #if choice is below - user is prompted with another choice
    elif choice_10 == "2" or choice_10 == "2." or "definitely" in choice_10 or "def" in choice_10:
        print("You know that singing your song can help you distract her. So you sing a song, but she looks at you all the time.")
        print("""
─═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═─୧⍤⃝─═──═──═──═──═──

Then she says: Beautiful song, Kolobok! But I am a little old and it's hard to hear you. 
Would you sit on my nose and sing it again? [Choose one option]
1. No! I will sing it from here.
2. Sure, Red Fox!""")
        
        choice_11 = input(prompt = "-> ").casefold()
        
        #if choice is below - user fails
        if choice_11 == "1" or choice_11 == "1." or "no! i will sing it from here" in choice_11 or "no" in choice_11 or "sing" in choice_11 or "here" in choice_11:
            print("Red Fox gets upset and starts chasing you to eat you, but you are slower than her and she catches you. And then we know what happened...")
            fail()
        
        #if choice is below - user goes to the final part
        elif choice_11 == "2" or choice_11 == "2." or "sure" in choice_11:
            print("You sit on her nose.")
            forest_fnl()
        
        #otherwise user is prompted with a Try Again menu
        else:
            print("""
There is no such answer :\ Try Again?
> Yes
> Exit""")
            try_again = input(prompt = "-> ").casefold()
            
            #user could replay the part
            if "yes" in try_again or try_again == "1":
                forest_6()
            
            #or lose
            else:
                fail()
    
    #Try Again menu pops up
    else:
        print("""
There is no such answer :\ Try Again?
> Yes
> Exit""")
        try_again = input(prompt = "-> ").casefold()
        
        #user could replay the part
        if "yes" in try_again or try_again == "1":
            forest_6()
            
        #or lose
        else:
            fail()

    #mandatory stage_3 continued (Final)
def forest_fnl():
    print("""
─═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═──═─୧⍤⃝─═──═──
    
What is your next move? [Choose one option]
1. Fine. Let's sing a song!
2. I will bounce on her head 5 times and knock her out!
""")
    
    choice_11 = input(prompt = "-> ")
    
    #if the choice is below - user is prompted to Restart the game from the beginning or finish the game
    if choice_11 == "1" or choice_11 == "1." or "fine. let's sing a song" in choice_11 or "fine" in choice_11 or "sing" in choice_11 or "song" in choice_11:
        print("""
You start singing you song and Red Fox flips Kolobok in the air, and in one snap of her jaws she swallowed you. 
This is the Original Ending of Kolobok Fairytale! But not the Win in this Game.

Want to try again?
> Yes
> No""")    
        
        #option to restart the game
        choice_12 = input(prompt = "-> ").casefold()
        
        if "yes" in try_again or try_again == "1":
            house()
        
        #or fail
        else:
            fail()
    
    #if user's choice is below - it's a straight line to finish
    elif choice_11 == "2" or choice_11 == "2." or "bounce on her head" in choice_11 or "bounce" in choice_11 or "her" in choice_11 or "head" in choice_11:
        print("""
You understand that Red Fox's behavior is suspicious and she probably wants to eat you. 
So you decide to jump on her head to knock her out!""")
        
        #defining number of presses
        presses = 5

        #while number of presses is above 0 - the loop will run
        while presses > 0:
            input(prompt = "<<Press Enter to jump!>>\n")
            
            #when the user pressed 5 times Enter - win() function runs
            presses -= 1

        win()

    #otherwise user is prompted to restart this part
    else:
        print("""
There is no such answer :\ Try Again?
> Yes
> Exit""")
        try_again = input(prompt = "-> ").casefold()
        
        if "yes" in try_again or try_again == "1":
            forest_6()
        else:
            fail()

    #fail function that will give user a choice of restarting the game or exiting the game
def fail():
    print("""
⢻⢭⡓⣆⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀ ⠀⠀⠀⠀⠸⣏⢖⡲⣅⠀⠀
⣣⢾⡛⣜⢫⣦⠀⠀⢀⣤⠴⡦⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢻⣸⢏⡝⣆⢀
⢿⣧⢹⣬⡷⣚⣒⣶⡾⣍⡞⡱⣞⡇⠀⠀⠀⠀⢀⣠⢤⠖⣦⡤⠤⡶⠦⠤⣤⢶⠲⠤⣄⠀⠀⠀⠀⠀⢀⡤⠶⢶⢤⡀⢸⣛⣮⢞⡜⡚
⠈⡷⣻⢏⠶⣙⢶⣼⠟⡼⣜⡵⠋⠀⠀⠀⣠⠞⡩⢴⣿⣿⣾⣹⠐⢢⢁⡾⡵⠚⢻⣷⣤⡙⠲⢄⠀⠀⢾⣍⡻⣌⢧⣷⡾⡞⣥⢫⡝⣃
⠀⢻⣿⢊⣟⣾⢫⢇⡻⣱⢺⠁⠀⠀⠀⡼⣡⣿⣄⣀⡿⣿⣿⡏⡇⢢⢸⡿⣷⣤⣼⠿⢿⣿⣷⣎⣷⠀⠈⠳⣵⡩⢖⡻⣱⢻⣌⡳⢎⡵
⠀⠀⢻⡧⢞⡧⣋⣮⣕⡣⢿⠀⠀⢀⡼⢃⣻⢿⣿⣿⣧⠾⠟⡙⣧⣂⣌⢣⡛⡿⠿⠷⠾⠿⠿⠣⣌⠳⡀⢰⢯⡱⣫⡶⢥⣛⢮⡓⣏⢶
⠀⠀⠈⢯⡧⣓⢧⡚⣽⣞⡾⠀⢀⡞⠠⣿⠀⡰⢂⣖⣤⣯⣾⣿⣿⣿⣿⣿⣿⣇⠄⣎⣱⣉⢎⡱⣘⡇⠹⡞⣮⢵⢯⣱⠳⡬⢧⡙⣦⠋
⠀⠀⠀⠈⠳⣭⢲⡹⢲⡞⠁⠀⣼⢐⠡⡙⠳⠗⡛⣩⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣯⡁⡉⠛⣶⣵⠋⡐⢿⠈⠻⣆⢧⡛⢜⣣⠟⠁⠀
⠀⠀⠀⠀⠀⠈⠉⠉⠁⠀⠀⢰⡇⢊⠔⡡⢊⠔⣸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⡈⠡⣿⢹⡄⢡⢚⣇⠀⠈⠉⠉⠉⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⡇⢊⠤⢑⠢⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⢹⠃⢢⢻⡄⢊⣏⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⣇⠌⢢⠁⢎⣿⣿⣿⣿⣿⣿⣿⠿⠟⠿⢿⣿⣿⣿⣿⣿⣿⣏⡄⢣⢺⡇⢼⡋⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢻⡊⠤⠉⢼⣿⣿⣿⣿⠿⠋⡄⠒⡌⢢⠐⡌⠻⣿⣿⣿⣿⣯⠛⢓⠛⣠⡾⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢧⡘⡏⣿⣿⣿⡿⠋⡄⠣⠌⡱⢈⠄⢣⠐⡡⠘⢿⣿⣿⣿⡐⣌⢒⣰⠏⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢳⡅⠸⠿⢛⡡⠘⡄⠣⡘⠄⠣⡘⠄⢣⠐⣉⠂⠻⢿⠿⠁⢼⡲⠋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢧⣁⠦⠟⡁⢣⠐⡡⠂⡍⠰⢁⠎⡄⠣⢄⡉⠲⢦⣂⣉⢴⠗⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
 ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠙⢲⢥⣂⠅⣂⠑⡈⢅⠊⡐⠌⢡⢂⣌⣡⠶⣛⣙⠋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
                             
                              The END
""")
    
    print("""
Are you sure you don't want to Restart the Journey?

> Yes
> No""")
    another_try = input(prompt = "-> ").casefold()
    
    #retry the game from the beginning
    if "yes" in another_try or another_try == "1":
        house()
        
    #end game fully
    else:
        print("\nGood luck in YOUR journey!")
        
    #win function
def win():
    print("""
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣾⡿⠳⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣤⡶⠶⢖⠦⣄⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣾⣷⡀⠀⠀⠀⠀⠀⠐⠋⠉⠉⠛⢷⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣰⠟⠁⠀⠀  ⠈⢳⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⡿⠋⠀⠀⠀⢀⣀⣠⠤⠤⠤⠤⠤⠤⠤⢌⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⢻⠀⠀⠀⠀ ⠀⠀⢸⠇⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣼⠁⣠⠤⠒⣋⡭⠤⠒⠒⠉⠉⡩⢟⣣⣤⣀⡢⣬⣉⠒⠤⣄⠀⠀⠀⠀⠀⠀⠀⠀⢼  ⠀⠀⠀⠀⠀⠀⡞⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⠖⣉⠴⠒⠉⠀⠀⠀⠀⠀⢀⣞⣴⠟⠋⠉⠛⢿⣾⣎⠑⢤⡀⠙⠢⣄⠀⠀⠀⠀⠀⠸⡄⠀⠀⠀⠀⠀⠀⣸⠃⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⡴⢋⡤⢊⣁⡀⠀⠀⠀⠀⠀⠀⠀⣞⣾⠃⠀⠀⠀⠀⠀⠹⣿⡄⠀⠱⡄⠀⠈⠑⣄⠀⠀⢀⣠⣽⠶⠶⠶⠒⠒⠒⠛⢤⣄⡀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⠋⡴⢋⢔⣭⣴⣿⣷⣤⠀⠀⠀⠀⠰⣽⠃⠀⠀⠀⠀⠀⠀⠀⢹⣇⠀⠀⠘⡄⠀⠀⠈⢳⣶⠟⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠯⠻⣦⡀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⡜⢡⠎⢠⢯⣿⠋⠁⠀⠈⠻⣷⠀⠀⠀⠀⡏⠀⠀⠀⠐⢷⢶⣄⠀⠀⣿⠀⠀⠐⠁⠀⠀⢰⡟⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠪⠙⣆⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⡞⢠⠃⠀⣮⡿⠁⠀⠀⠀⠀⠀⠻⣇⠀⠀⢸⡇⠀⠀  ⠀⣸⣷⣻⡄⠀⣿⠀⠀⠀⠀⠀⠀⣏⠓⠒⢀⣀⣀⣀⣀⣀⣀⣀⣀⠀⢠⠖⠀⠀⠀⠘⡄
⠀⠀⣀⣠⣤⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡞⢀⠇⠀⢰⣿⠇⠀⠀⠀⠀⠶⣶⡄⢹⠀⠀⠀⡇⠀⠀⣾⢹⣿⣿⣏⡇⠀⣿⠀⠀⣀⣤⡤⠤⣼⣶⠿⠛⠉⠀⠀⠀⠀⠀⠀⠉⠙⡇⠀⠀⠀⠀⠀⠀
⣠⢾⠋⠀⠀⠈⠻⡷⣄⠀⠀⠀⠀⠀⠀⢰⠁⠸⠀⠀⠸⣿⠀⠀⠀⠀⣄⣀⣷⣽⣸⠀⠀⠀⣇⠀⠀⠸⣞⣿⣅⣽⠁⢀⣇⣴⠞⠋⠁⠀⣼⠏⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠇⠀⠀⠀⠀⠀⠀
⡇⠘⠂⠀⠀⠀⠀⠁⠘⡆⠀⠀⠀⠀⠀⡏⠀⠀⠀⠀⢰⣿⠀⠀⠀⠀⣇⣿⣿⣿⣿⠀⠀⠀⠸⡄⠀⠀⠙⠧⠽⠃⠀⡼⠋⠀⠀⠀⠀⠀⣯⠦⠄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡀⠀⠀⠀⠀⠀⠀⠀
⢳⡀⠀⠀⠀⠀⠀⠀⢀⣹⣤⣤⣤⣤⣄⡇⠀ ⠀⠀⠀⣿⠀⠀⠀⠀⢻⡽⠿⣾⢹⠀⠀⠀⠀⠻⡄⠀⠀⠀⠀⢠⠞⠁⠀⣀⣀⡀⠀⠀⠘⢧⡀⣠⣤⡶⠖⠛⠛⠛⠒⠒⡞⠀⠀⠀⠀⠀⠀⢀⠀
⠀⠉⠳⣄⠀⢀⡤⡺⠛⠉⠀⠀⠀⠀⠈⣻⢦⠀⠀⠀⠀⢻⡆⠀⠀⠀⠈⠻⠟⢁⡎⠀⠀⠀⠀⠀⠙⠦⣄⣀⣤⠟⠀⠀⠉⣀⣀⣀⡉⠂⠀⠀⣽⣏⠁⠀⠀⠀⠀⠀⠀⠀⢇⠀⠀⠀⠀⠀⢠⡞⠀
⠀⠀⠀⢈⣷⠋⠀⠁⠀⠀⠀⠀⠀⢈⣩⣤⣼⣧⣤⡀⠀⠀⠻⡄⠀⠀⠀⠀⢀⡼⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠋⠀⠀⣈⣭⠵⠒⠋⠉⠂⠀⠀⠹⡌⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⡴⠋⠀⠀
⠀⠀⠀⣾⠋⠀⠀⠀⠀⠀⢀⡤⠞⠉⠉⠀⠀⠀⠈⣻⡆⠀⣀⣙⡦⠤⣀⣤⠊⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣠⠴⠋⣡⡏⠀⠀⠀⠀⠀⠀⠀⠀⠙⠲⣄⡀⠀⠀⠀⠀⠀⠀⣀⣠⠴⠋⠁⠀⠀⠀
⠀⠀⢸⠇⠀⠀⠀⠀⢀⡶⠉⠀⠀⠀⠀⠀⠀⠀⠈⠁⡧⠋⠉⠁⠀⠀⠀⠘⠀⠀⠀⠀⠀⠀⠀⢀⣠⠴⠚⠉⠀⢀⣴⣿⠇⠀⠀⠀⠀⠀⠀⠀⠀⠀⣰⠁⠈⠉⠉⠉⠉⠉⠉⠁⠀⠀⠀⠀⠀⠀⠀
⠀⠀⢸⠀⠀⠀⠉⠑⢏⠀⠀⠀⠀⠀⠀⣀⣤⠶⠶⠾⣧⡀⠀⠀⠀⠀⠀⣤⣤⣤⣤⡤⠒⠒⠉⠁⠀⠀⣀⣤⣶⠿⢿⡿⠀⠀⠀⠀⠀⠀⠀⠀⢀⡶⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠈⡆⠀⠀⠀⠀⠈⠇⠀⠀⢀⡤⠚⠉⠀⠀⠀⠐⠁⡇⠀⠀⠀⠀⠀⠘⢿⣿⣿⣿⣶⣶⣶⣶⣾⠿⣿⡟⠁⠀⣼⠃⠀⠀⠀⠀⠀⣠⠞⣠⡟⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠹⡄⠀⠀⠀⠀⠀⠀⠉⠻⡄⠀⠀⠀⠀⠀⠀⣰⠁⠀⠀⠀⠀⠀⠀⠈⢿⣿⣿⣿⣿⣿⣿⠃⣠⠏⠀⠀⣰⠏⠀⠀⠀⠀⠠⠞⢁⡴⠋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠙⣄⠀⠀⠀⠀⠀⠀⠀⠊⠀⠀⠀⠀⢀⡴⠋⠳⢄⠀⠀⠀⠀⠀⠀⠀⠹⣿⣿⣿⣿⠁⠊⠀⠀⢀⡰⠋⠀⠀⠀⠀⠀⣠⡴⠋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠈⠑⠦⣀⡀⠀⠀⠀⠀⠀⣀⡠⠖⠋⠀⠀⠀⠀⠙⠢⢄⡀⠀⠀⠀⠀⠈⠛⢿⣇⣀⣀⣠⠴⠋⠀⠀⠀⢀⣀⠤⠚⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠉⠒⠒⠚⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠙⠒⠤⢤⣀⣀⣀⣀⣀⣀⣀⣀⡠⠤⠖⠚⠉⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀


It took you some time but you made it! Through all the challenges!
And besides that, you know about a traditional Russian fairytale (with some modifications).""")


house()
