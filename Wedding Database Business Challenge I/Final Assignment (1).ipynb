# %%
import pandas as pd

# importing excel to Jupyter Notebook

file = './wedding_cost_data.xlsx'

# reading in the data
w_planner = pd.read_excel(io = file,
               sheet_name = 'wedding_cost_data',
               header = 0)

# variables for dynamic printing of category

category1 = w_planner.category[0].title() # flowers
category2 = w_planner.category[4].title() # venues
category3 = w_planner.category[5].title() # music
category4 = w_planner.category[6].title() # jewelry
category5 = w_planner.category[7].title() # photo and video
category6 = w_planner.category[8].title() # hair and makeup
category7 = w_planner.category[9].title() # dress and attire
category8 = w_planner.category[10].title() # catering
category9 = w_planner.category[13].title() # rentals
category10 = w_planner.category[28].title() # invitations


# variables for dynamic printing of vendor_name

vendor_name1 = w_planner.vendor_name[0].title()
vendor_name2 = w_planner.vendor_name[4].title()
vendor_name3 = w_planner.vendor_name[5].title()
vendor_name4 = w_planner.vendor_name[6].title()
vendor_name5 = w_planner.vendor_name[7].title()
vendor_name6 = w_planner.vendor_name[8].title()
vendor_name7 = w_planner.vendor_name[9].title()
vendor_name8 = w_planner.vendor_name[10].title()
vendor_name9 = w_planner.vendor_name[13].title()
vendor_name10 = w_planner.vendor_name[28].title()


# variables for dynamic printing of budget_level

budget_level1 = w_planner.budget_level[0].title()
budget_level2 = w_planner.budget_level[4].title()

# variables for dynamic printing of item_name

item_name1 = w_planner.item_name[0].title()
item_name2 = w_planner.item_name[1].title()
item_name3 = w_planner.item_name[2].title()
item_name4 = w_planner.item_name[3].title()
item_name5 = w_planner.item_name[4].title()
item_name6 = w_planner.item_name[5].title()
item_name7 = w_planner.item_name[6].title()
item_name8 = w_planner.item_name[7].title()
item_name9 = w_planner.item_name[8].title()
item_name10 = w_planner.item_name[9].title()
item_name11 = w_planner.item_name[10].title()
item_name12 = w_planner.item_name[11].title()
item_name13 = w_planner.item_name[12].title()
item_name14 = w_planner.item_name[13].title()
item_name15 = w_planner.item_name[14].title()
item_name16 = w_planner.item_name[15].title()
item_name17 = w_planner.item_name[16].title()
item_name18 = w_planner.item_name[17].title()
item_name19 = w_planner.item_name[18].title()
item_name20 = w_planner.item_name[19].title()
item_name21 = w_planner.item_name[20].title()
item_name22 = w_planner.item_name[21].title()
item_name23 = w_planner.item_name[22].title()
item_name24 = w_planner.item_name[23].title()
item_name25 = w_planner.item_name[24].title()
item_name26 = w_planner.item_name[25].title()
item_name27 = w_planner.item_name[26].title()
item_name28 = w_planner.item_name[27].title()
item_name29 = w_planner.item_name[28].title()
item_name30 = w_planner.item_name[29].title()
item_name31 = w_planner.item_name[30].title()



# variables for dynamic printing of price_per_item

price_per_item1 = w_planner.price_per_item[0].round(decimals = 2)
price_per_item2 = w_planner.price_per_item[1].round(decimals = 2)
price_per_item3 = w_planner.price_per_item[2].round(decimals = 2)
price_per_item4 = w_planner.price_per_item[3].round(decimals = 2)
price_per_item5 = w_planner.price_per_item[4].round(decimals = 2)
price_per_item6 = w_planner.price_per_item[5].round(decimals = 2)
price_per_item7 = w_planner.price_per_item[6].round(decimals = 2)
price_per_item8 = w_planner.price_per_item[7].round(decimals = 2)
price_per_item9 = w_planner.price_per_item[8].round(decimals = 2)
price_per_item10 = w_planner.price_per_item[9].round(decimals = 2)
price_per_item11 = w_planner.price_per_item[10].round(decimals = 2)
price_per_item12 = w_planner.price_per_item[11].round(decimals = 2)
price_per_item13 = w_planner.price_per_item[12].round(decimals = 2)
price_per_item14 = w_planner.price_per_item[13].round(decimals = 2)
price_per_item15 = w_planner.price_per_item[14].round(decimals = 2)
price_per_item16 = w_planner.price_per_item[15].round(decimals = 2)
price_per_item17 = w_planner.price_per_item[16].round(decimals = 2)
price_per_item18 = w_planner.price_per_item[17].round(decimals = 2)
price_per_item19 = w_planner.price_per_item[18].round(decimals = 2)
price_per_item20 = w_planner.price_per_item[19].round(decimals = 2)
price_per_item21 = w_planner.price_per_item[20].round(decimals = 2)
price_per_item22 = w_planner.price_per_item[21].round(decimals = 2)
price_per_item23 = w_planner.price_per_item[22].round(decimals = 2)
price_per_item24 = w_planner.price_per_item[23].round(decimals = 2)
price_per_item25 = w_planner.price_per_item[24].round(decimals = 2)
price_per_item26 = w_planner.price_per_item[25].round(decimals = 2)
price_per_item27 = w_planner.price_per_item[26].round(decimals = 2)
price_per_item28 = w_planner.price_per_item[27].round(decimals = 2)
price_per_item29 = w_planner.price_per_item[28].round(decimals = 2)
price_per_item30 = w_planner.price_per_item[29].round(decimals = 2)
price_per_item31 = w_planner.price_per_item[30].round(decimals = 2)




# variables for dynamic printing for quantity

quantity1 = w_planner.quantity[0]
quantity2 = w_planner.quantity[1]
quantity3 = w_planner.quantity[2]
quantity4 = w_planner.quantity[3]
quantity5 = w_planner.quantity[4]
quantity6 = w_planner.quantity[5]
quantity7 = w_planner.quantity[6]
quantity8 = w_planner.quantity[7]
quantity9 = w_planner.quantity[8]
quantity10 = w_planner.quantity[9]
quantity11 = w_planner.quantity[10]
quantity12 = w_planner.quantity[11]
quantity13 = w_planner.quantity[12]
quantity14 = w_planner.quantity[13]
quantity15 = w_planner.quantity[14]
quantity16 = w_planner.quantity[15]
quantity17 = w_planner.quantity[16]
quantity18 = w_planner.quantity[17]
quantity19 = w_planner.quantity[18]
quantity20 = w_planner.quantity[19]
quantity21 = w_planner.quantity[20]
quantity22 = w_planner.quantity[21]
quantity23 = w_planner.quantity[22]
quantity24 = w_planner.quantity[23]
quantity25 = w_planner.quantity[24]
quantity26 = w_planner.quantity[25]
quantity27 = w_planner.quantity[26]
quantity28 = w_planner.quantity[27]
quantity29 = w_planner.quantity[28]
quantity30 = w_planner.quantity[29]
quantity31 = w_planner.quantity[30]

# variables for dynamic printing for subtotal

subtotal1 = w_planner.subtotal[0].round(decimals = 2)
subtotal2 = w_planner.subtotal[1].round(decimals = 2)
subtotal3 = w_planner.subtotal[2].round(decimals = 2)
subtotal4 = w_planner.subtotal[3].round(decimals = 2)
subtotal5 = w_planner.subtotal[4].round(decimals = 2)
subtotal6 = w_planner.subtotal[5].round(decimals = 2)
subtotal7 = w_planner.subtotal[6].round(decimals = 2)
subtotal8 = w_planner.subtotal[7].round(decimals = 2)
subtotal9 = w_planner.subtotal[8].round(decimals = 2)
subtotal10 = w_planner.subtotal[9].round(decimals = 2)
subtotal11 = w_planner.subtotal[10].round(decimals = 2)
subtotal12 = w_planner.subtotal[11].round(decimals = 2)
subtotal13 = w_planner.subtotal[12].round(decimals = 2)
subtotal14 = w_planner.subtotal[13].round(decimals = 2)
subtotal15 = w_planner.subtotal[14].round(decimals = 2)
subtotal16 = w_planner.subtotal[15].round(decimals = 2)
subtotal17 = w_planner.subtotal[16].round(decimals = 2)
subtotal18 = w_planner.subtotal[17].round(decimals = 2)
subtotal19 = w_planner.subtotal[18].round(decimals = 2)
subtotal20 = w_planner.subtotal[19].round(decimals = 2)
subtotal21 = w_planner.subtotal[20].round(decimals = 2)
subtotal22 = w_planner.subtotal[21].round(decimals = 2)
subtotal23 = w_planner.subtotal[22].round(decimals = 2)
subtotal24 = w_planner.subtotal[23].round(decimals = 2)
subtotal25 = w_planner.subtotal[24].round(decimals = 2)
subtotal26 = w_planner.subtotal[25].round(decimals = 2)
subtotal27 = w_planner.subtotal[26].round(decimals = 2)
subtotal28 = w_planner.subtotal[27].round(decimals = 2)
subtotal29 = w_planner.subtotal[28].round(decimals = 2)
subtotal30 = w_planner.subtotal[29].round(decimals = 2)
subtotal31 = w_planner.subtotal[30].round(decimals = 2)


subtotal_f = subtotal1 + subtotal2 + subtotal3 + subtotal4



c_budget = 70000 # client's budget

total = w_planner['subtotal'].sum().round(decimals = 2) #subtotal sum
budget_level = budget_level1 + "/" + budget_level2 # budget level for the client to see in the receipt




print(f""" 
_______________________________________________________________________________________________________________ 


                                            Wedding Cost Breakdown
            

_______________________________________________________________________________________________________________ 

Client's budget: $ {c_budget}
Wedding's budget level: {budget_level}

_______________________________________________________________________________________________________________



Category          | Vendor Name            | Item Name        |Price per Item       |Quantity | Subtotal
_______________________________________________________________________________________________________________                  
{category1: <18}|{vendor_name1: <22}  |{item_name1: <18}| $ {price_per_item1: <18}| {quantity1: <8}| $ {subtotal1: <8}
                  |{vendor_name1: <24}|{item_name2: <18}| $ {price_per_item2: <18}| {quantity2: <8}| $ {subtotal2: <8}
                  |{vendor_name1: <24}|{item_name3: <18}| $ {price_per_item3: <18}| {quantity3: <8}| $ {subtotal3: <8}
                  |{vendor_name1: <24}|{item_name4: <18}| $ {price_per_item4: <18}| {quantity4: <8}| $ {subtotal4: <8}
{category2: <16}  |{vendor_name2: <5}|{item_name5: <18}| $ {price_per_item5: <18}| {quantity5: <8}| $ {subtotal5: <8}
{category3: <16}  |{vendor_name3: <24}|{item_name6: <18}| $ {price_per_item6: <18}| {quantity6: <8}| $ {subtotal6: <8}
{category4: <16}  |{vendor_name4: <24}|{item_name7: <18}| $ {price_per_item7: <18}| {quantity7: <8}| $ {subtotal7: <8}
{category5: <16}  |{vendor_name5: <24}|{item_name8: <18}| $ {price_per_item8: <18}| {quantity8: <8}| $ {subtotal8: <8}
{category6: <16}  |{vendor_name6: <24}|{item_name9: <18}| $ {price_per_item9: <18}| {quantity9: <8}| $ {subtotal9: <8}
{category7: <16}  |{vendor_name7: <24}|{item_name10: <18}| $ {price_per_item10: <18}| {quantity10: <8}| $ {subtotal10: <8}
{category8: <16}  |{vendor_name8: <24}|{item_name11: <18}| $ {price_per_item11: <18}| {quantity11: <8}| $ {subtotal11: <8}
                  |{vendor_name8: <24}|{item_name12: <18}| $ {price_per_item12: <18}| {quantity12: <8}| $ {subtotal12: <8}
                  |{vendor_name8: <24}|{item_name13: <18}| $ {price_per_item13: <18}| {quantity13: <8}| $ {subtotal13: <8}
{category9: <16}  |{vendor_name9: <24}|{item_name14: <18}| $ {price_per_item14: <18}| {quantity14: <8}| $ {subtotal14: <8}
                  |{vendor_name9: <5}|{item_name15: <18}| $ {price_per_item15: <18}| {quantity15: <8}| $ {subtotal15: <8}
                  |{vendor_name9: <5}|{item_name16: <18}| $ {price_per_item16: <18}| {quantity16: <8}| $ {subtotal16: <8}
                  |{vendor_name9: <5}|{item_name17: <18}| $ {price_per_item17: <18}| {quantity17: <8}| $ {subtotal17: <8}
                  |{vendor_name9: <5}|{item_name18: <18}| $ {price_per_item18: <18}| {quantity18: <8}| $ {subtotal18: <8}
                  |{vendor_name9: <5}|{item_name19: <18}| $ {price_per_item19: <18}| {quantity19: <8}| $ {subtotal19: <8}
                  |{vendor_name9: <5}|{item_name20: <18}| $ {price_per_item20: <18}| {quantity20: <8}| $ {subtotal20: <8}
                  |{vendor_name9: <5}|{item_name21: <18}| $ {price_per_item21: <18}| {quantity21: <8}| $ {subtotal21: <8}
                  |{vendor_name9: <5}|{item_name22: <18}| $ {price_per_item22: <18}| {quantity22: <8}| $ {subtotal22: <8}
                  |{vendor_name9: <5}|{item_name23: <18}| $ {price_per_item23: <18}| {quantity23: <8}| $ {subtotal23: <8}
                  |{vendor_name9: <5}|{item_name24: <18}| $ {price_per_item24: <18}| {quantity24: <8}| $ {subtotal24: <8}
                  |{vendor_name9: <5}|{item_name25: <18}| $ {price_per_item25: <18}| {quantity25: <8}| $ {subtotal25: <8}
                  |{vendor_name9: <5}|{item_name26: <18}| $ {price_per_item26: <18}| {quantity26: <8}| $ {subtotal26: <8}
                  |{vendor_name9: <5}|{item_name27: <18}| $ {price_per_item27: <18}| {quantity27: <8}| $ {subtotal27: <8}
                  |{vendor_name9: <5}|{item_name28: <18}| $ {price_per_item28: <18}| {quantity28: <8}| $ {subtotal28: <8}
{category10: <17} |{vendor_name10: <24}|{item_name29: <18}| $ {price_per_item29: <18}| {quantity29: <8}| $ {subtotal29: <8}
                  |{vendor_name10: <24}|{item_name30: <18}| $ {price_per_item30: <18}| {quantity30: <8}| $ {subtotal30: <8}
                  |{vendor_name10: <24}|{item_name31: <18}| $ {price_per_item31: <18}| {quantity31: <8}| $ {subtotal31: <8}
_______________________________________________________________________________________________________________ 

Total:                                                                                          $ {total}  
                  
                  
                  
""")
# Out:
#
# _______________________________________________________________________________________________________________
#
#
#                                             Wedding Cost Breakdown
#
#
# _______________________________________________________________________________________________________________
#
# Client's budget: $ 70000
# Wedding's budget level: Moderate/Luxury
#
# _______________________________________________________________________________________________________________
#
#
#
# Category          | Vendor Name            | Item Name        |Price per Item       |Quantity | Subtotal
# _______________________________________________________________________________________________________________
# Flowers           |Dragonfly Floristic     |Bouquets          | $ 199.0             | 3       | $ 597.0
#                   |Dragonfly Floristic     |Centerpieces      | $ 169.0             | 18      | $ 3042.0
# ...

# %%
w_planner
# Out:
#             category               vendor_name budget_level  \
# 0            flowers       dragonfly floristic     moderate
# 1            flowers       dragonfly floristic     moderate
# 2            flowers       dragonfly floristic     moderate
# 3            flowers       dragonfly floristic     moderate
# 4             venues  half moon bay golf links       luxury
# 5              music                sf deejays       luxury
# 6            jewelry        sausolito jewelers       luxury
# 7    photo and video               silver seas       luxury
# 8    hair and makeup                shannon le       luxury
# 9   dress and attire         casablanca bridal       luxury
# 10          catering          fraiche catering       luxury
# 11          catering          fraiche catering       luxury
# 12          catering          fraiche catering       luxury
# 13            rental  all seasons event rental     moderate
# 14            rental  all seasons event rental     moderate
# ...
