# %%
import random 
random.seed(148) #writing the seed value to reuse the random output later

# printing directions for the game

print(f""" 
{'🧠🔥🦸🏻‍♀️🪨' * 12} 
      
DIRECTIONS:

    Get ready to embark on a laughter-filled journey as we introduce the 
fantastic Team 6! Brace yourself for a wild ride, because once you fill in 
the blanks, our team's introduction will leap off the page and into your 
heart. 

The blanks are your canvas, and humor is your paint – 
let the Masterpiece Begin <(^_^)> !
\n""")

# creating list for first conditional statement for a random selection of a name if there is an error in the input

teams_lst = ['Flapjacks', 'Snicker Snatchers', 'Chuckle Checkers', 'Jolly Lollies', 'Wit Wonders', 'Whoopee Wizards']

# first input and press 'enter' to continue

your_team  = input(prompt = """Type a team of your choice and Press <<Enter>> to start your journey: 

Flapjacks 
Snicker Snatchers
Chuckle Checkers
Jolly Lollies
Wit Wonders
Whoopee Wizards
\n""").title() # adding a title() method to have every word of the input capitalized

# first conditional statement will print your chosen/defined team name

if your_team in teams_lst: # if the chosen team is in our team
    print('Nice! You chose',your_team,'!') # print the following output with the chosen team
elif your_team == "Fantastic 4":
    print("Yay! You guessed the real name of our Fantastic Team!!!") # if they put Fantastic Four it will print a wonton!
else:
    print('Your choice is not in our list so we have selected one for you:',random.choice(teams_lst)) # print the following output with the random (predefined) team name

random.seed(148) # we repeat random seed to have the same 'random' result

# second conditional statement stores values in your team 
    
if   your_team in teams_lst: # if the input is in our list
     your_team = your_team # the input will be stored in your_team
elif your_team == "Fantastic 4": # if the input is Fantastic 4
    your_team = "Fantastic 4" #your_team will equal to Fantastic 4
else:
    your_team = random.choice(teams_lst) # the input will be defined by a random function with seed (148) 

# second input with a title() method to have every word of the input capitalized
name_1     = input(prompt = "What is your fanciest snack?\n").title()

# third input with a casefold() method to avoid problems involving case sensitivity

dish_1     = input(prompt = 'What is your favorite dish?\n').casefold()

if dish_1 == "chicken": 
    print("Wow!!!??? You guessed Emmanuel's Favorite Dish!!!") # if they put chciken it will print a wonton!    
else:
    dish_1 = dish_1
    
# fourth input with a title() method to have every word of the input capitalized

name_2     = input(prompt = """If you could have any political or famous figure as your roommate, who would it be?
(e.g Trump)\n""").title()

# fifth input with a lower() method to avoid problems involving case sensitivity

emotion_1  = input(prompt = 'A word showing emotion? (ending with -ness, ie. Sadness)\n').lower()

# sixth input with a title() method to have every word of the input capitalized

name_3     = input(prompt = "Who is your favorite singer?\n").title()

# seventh input with a casefold() method to avoid problems involving case sensitivity

doing      = input(prompt = 'Your favorite kind of chore at home (verb + noun, i.e doing laundry, cleaning dishes):\n').casefold()

if doing == "cleaning dishes": 
    print("What!!!??? Sofi hates that!!!") # if they put cleaning dishes it will print a wonton!
else:
    doing = doing # otherwise input value stays the same

# eighth input with a casefold() method to avoid problems involving case sensitivity

name_4     = input(prompt = 'What is your spirit animal? (plural)\n').casefold()

if name_4 == "zebras":
    print("How did you do it??? You guessed Victor's Spirit Animals!!!") # if they put zebras it will print a wonton!
else:
    name_4 = name_4 
    
 # ninth input with a lower() method to avoid problems involving case sensitivity

traits     = input(prompt = """Two personality traits of your grandmother 
(abstract nouns, i.e. freedom and love, kindness and joy):\n""").lower()

print(f"""
\f

Are you ready to see your story? Answer this last question to be amused:

ヽ༼ ຈل͜ຈ༼ ▀̿̿Ĺ̯̿̿▀̿ ̿༽Ɵ͆ل͜Ɵ͆ ༽ﾉ

""")

# tenth input with a casefold() method to avoid problems involving case sensitivity

pet_peeve  = input(prompt = 'What is your pet peeve? (e.g Loud chewing, Slow walkers)\n').casefold()

if pet_peeve == "loud chewing": # if they put loud chewing it will print a wonton!
    print("You did it!! You guessed Chewy's Pet Peeve!!!") 
else:
    pet_peeve = pet_peeve # otherwise the input will stay as it is

# print the result of the dynamic introduction
# print 80 stars to look pretty

print(f"""
\f
{'☆' * 80}


    We are the {your_team}, but don't expect any superhero stuff from us; 
we're here to conquer real-world challenges!

    Leading our squad is Victor, aka Mr. {name_1}. His brain is like a 
{dish_1}, constantly steering us forward. His wisdom and insights 
is our guiding light.

    Then there's Emmanuel, our "chill bro." He's so chill, even ice cubes 
might get jealous. But don't be deceived; under that calm exterior burns 
a fiery passion reminiscent of the Human {name_2}. Emmanuel's enthusiasm 
ignites our {emotion_1}, turning every challenge into a thrilling journey.

    Need things done invisibly? That is where our Invisible {name_3} – Chewy 
comes in, {doing} behind the scenes, pulling off the impossible without
breaking a sweat. She ensures seamless coordination and influences outcomes
subtly.

    Sofia, the pocket-sized powerhouse of our team, she might look like she 
would need a booster seat at a roller coaster, but do not be fooled – 
underneath that petite exterior is a force of nature that even {name_4} 
would nod approvingly at. She brings {traits} to the team. 
Her presence inspires us, emphasizing that true strength encompasses more 
than just muscle.

    Our team is united by a passion for {pet_peeve}. Together, we're 
more than just a team; we're a fantastic force, ready to face any 
challenge head-on.


{'༼ つ ◕_◕ ༽つ   o()xxxx[{::::::::::::::::::>   ─=≡Σ((( つ◕ل͜◕)つ'}
""")
# print Team 6 chasing Chase to get a 100% in the assignment

# %% [markdown]
# DON"T LOOK HERE YET! IT'S OUR ORIGINAL INTRODUCTION.
#
# We are the Fantastic 4, but don't expect any superhero stuff from us; we're here to conquer real-world challenges!
#
# Leading our squad is Victor, aka Mr. Fantastic. His brain is like a success-oriented GPS, constantly steering us forward. His wisdom and insights is our guiding light.
#
# Then there's Emmanuel, our "chill bro." He's so chill, even ice cubes might get jealous. But don't be deceived; under that calm exterior burns a fiery passion reminiscent of the Human Torch. Emmanuel's enthusiasm ignites our spirits, turning every challenge into a thrilling journey.
#
# Need things done invisibly? That is where our Invisible Wizard – Chewy comes in, making magic behind the scenes, pulling off the impossible without breaking a sweat. She ensures seamless coordination and influences outcomes subtly.
#
# Sofia, the pocket-sized powerhouse of our team, she might look like she would need a booster seat at a roller coaster, but do not be fooled – underneath that petite exterior is a force of nature that even the Thing would nod approvingly at. She brings strength and resilience to the team. Her presence inspires us, emphasizing that true strength encompasses more than just muscle.
#
# Our team is united by a passion for learning and commitment to excellence. Together, we're more than just a team; we're a fantastic force, ready to face any challenge head-on.
